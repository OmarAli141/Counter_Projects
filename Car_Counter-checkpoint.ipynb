# %%
from ultralytics import YOLO
import cv2
import cvzone
import math
from sort import *

# %%
# Video capture from a file
cap = cv2.VideoCapture('cars.mp4')

# Loading the YOLO model
model = YOLO('../Yolo-Weights/yolov8n.pt')

# Object classes
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]

paused = False  # To control the paused state of the video

# Load the mask image
mask = cv2.imread("mask-950x480.png")

# Tracking
tracker = Sort(max_age=20, min_hits=3, iou_threshold=0.3)

# Line limits
limits = [400, 297, 673, 297]
totalCount = set()  # Use a set to avoid duplicate counts

# Dictionary to map SORT IDs to new IDs starting from 1
id_map = {}
next_id = 1

while True:
    if not paused:
        success, img = cap.read()
        if not success:
            break

        # Resize mask to match the dimensions of img
        mask = cv2.resize(mask, (img.shape[1], img.shape[0]))

        # Apply bitwise AND operation
        imgRegion = cv2.bitwise_and(img, mask)
        
        imgGraphics = cv2.imread("graphics.png",cv2.IMREAD_UNCHANGED)
        img = cvzone.overlayPNG(img,imgGraphics,(0,0))
        results = model(imgRegion, stream=True)
        detections = np.empty((0, 5))
        for r in results:
            boxes = r.boxes
            for box in boxes:
                x1, y1, x2, y2 = box.xyxy[0]
                x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
                w, h = x2 - x1, y2 - y1

                # Confidence and class name
                conf = math.ceil((box.conf[0] * 100)) / 100
                cls = int(box.cls[0])
                currentClass = classNames[cls]

                if currentClass in ["car", "truck", "bus", "motorbike"] and conf > 0.3:
                    currentArray = np.array([x1, y1, x2, y2, conf])
                    detections = np.vstack((detections, currentArray))

    resultsTracker = tracker.update(detections)
    cv2.line(img, (limits[0], limits[1]), (limits[2], limits[3]), (0, 0, 255), 5)

    current_count = set()  # Track current frame counts
    for result in resultsTracker:
        x1, y1, x2, y2, ID = result
        x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
        w, h = x2 - x1, y2 - y1

        # Reassign ID to start from 1
        if ID not in id_map:
            id_map[ID] = next_id
            next_id += 1
        new_id = id_map[ID]
        print(f"ID: {new_id}, Bounding Box: {[x1, y1, x2, y2]}")
        cvzone.cornerRect(img, (x1, y1, w, h), l=9, rt=2, colorR=(255, 0, 255))
        cvzone.putTextRect(img, f'{new_id}', (max(0, x1), max(35, y1)),
                           offset=10, scale=2, thickness=3)

        cx, cy = x1 + w // 2, y1 + h // 2
        cv2.circle(img, (cx, cy), 5, (255, 0, 255), cv2.FILLED)

        if limits[0] < cx < limits[2] and limits[1] - 15 < cy < limits[1] + 15:
            if new_id not in totalCount:
                totalCount.add(new_id)  # Add ID to the set
                cv2.line(img, (limits[0], limits[1]), (limits[2], limits[3]), (0, 255,0), 5)
                    
#     cvzone.putTextRect(img, f'Count: {len(totalCount)}', (50, 50))
    cv2.putText(img,str(len(totalCount)),(255,100),cv2.FONT_HERSHEY_PLAIN,5,(255,0,0),8)
    cv2.imshow("Image", img)
    key = cv2.waitKey(1) & 0xFF

    if key == ord('p'):  # Pause the video
        paused = True
    elif key == ord('r'):  # Resume the video
        paused = False
    elif key == ord('q'):  # Quit the video
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 5 cars, 684.5ms
# Speed: 68.1ms preprocess, 684.5ms inference, 129.5ms postprocess per image at shape (1, 3, 384, 640)
# ID: 1, Bounding Box: [572, 318, 651, 429]
# ID: 2, Bounding Box: [573, 363, 626, 429]
# ID: 3, Bounding Box: [377, 347, 496, 459]
# ID: 4, Bounding Box: [454, 225, 509, 272]
#
# 0: 384x640 5 cars, 129.1ms
# Speed: 8.5ms preprocess, 129.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 1, Bounding Box: [569, 320, 650, 436]
# ID: 2, Bounding Box: [571, 371, 627, 437]
# ID: 3, Bounding Box: [372, 349, 494, 462]
# ID: 4, Bounding Box: [453, 227, 508, 273]
#
# 0: 384x640 4 cars, 84.1ms
# Speed: 3.0ms preprocess, 84.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
# ID: 5, Bounding Box: [522, 180, 557, 200]
# ID: 3, Bounding Box: [353, 366, 479, 480]
# ID: 4, Bounding Box: [447, 234, 501, 280]
#
# 0: 384x640 5 cars, 87.4ms
# Speed: 4.0ms preprocess, 87.4ms inference, 28.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 3, Bounding Box: [334, 390, 456, 486]
# ID: 4, Bounding Box: [437, 243, 494, 291]
#
# 0: 384x640 4 cars, 95.1ms
# Speed: 3.0ms preprocess, 95.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 3, Bounding Box: [318, 415, 434, 489]
# ID: 4, Bounding Box: [425, 251, 487, 303]
#
# 0: 384x640 4 cars, 93.3ms
# Speed: 4.6ms preprocess, 93.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 5, Bounding Box: [510, 182, 551, 211]
# ID: 3, Bounding Box: [308, 440, 410, 490]
# ID: 4, Bounding Box: [415, 260, 478, 313]
#
# 0: 384x640 3 cars, 83.8ms
# Speed: 4.6ms preprocess, 83.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 6, Bounding Box: [613, 205, 658, 254]
# ID: 5, Bounding Box: [508, 185, 549, 214]
# ID: 4, Bounding Box: [404, 268, 470, 324]
#
# 0: 384x640 3 cars, 81.3ms
# Speed: 2.0ms preprocess, 81.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 6, Bounding Box: [608, 213, 658, 265]
# ID: 5, Bounding Box: [503, 187, 545, 219]
# ID: 4, Bounding Box: [391, 277, 461, 336]
#
# 0: 384x640 4 cars, 77.3ms
# Speed: 2.0ms preprocess, 77.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 6, Bounding Box: [605, 222, 659, 278]
# ID: 5, Bounding Box: [499, 188, 543, 223]
# ID: 4, Bounding Box: [375, 287, 450, 351]
#
# 0: 384x640 6 cars, 75.8ms
# Speed: 3.0ms preprocess, 75.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# ID: 6, Bounding Box: [600, 231, 659, 292]
# ID: 5, Bounding Box: [497, 193, 541, 228]
# ID: 4, Bounding Box: [359, 299, 439, 367]
#
# 0: 384x640 4 cars, 91.3ms
# Speed: 5.0ms preprocess, 91.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 6, Bounding Box: [592, 243, 655, 308]
# ID: 5, Bounding Box: [492, 196, 538, 233]
# ID: 4, Bounding Box: [340, 312, 426, 385]
#
# 0: 384x640 4 cars, 83.9ms
# Speed: 1.5ms preprocess, 83.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 6, Bounding Box: [585, 254, 653, 324]
# ID: 5, Bounding Box: [488, 201, 534, 239]
# ID: 4, Bounding Box: [320, 326, 412, 404]
#
# 0: 384x640 5 cars, 77.8ms
# Speed: 8.0ms preprocess, 77.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 6, Bounding Box: [579, 268, 652, 345]
# ID: 5, Bounding Box: [483, 205, 530, 244]
# ID: 4, Bounding Box: [296, 342, 394, 426]
#
# 0: 384x640 6 cars, 74.7ms
# Speed: 3.0ms preprocess, 74.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 7, Bounding Box: [572, 198, 610, 233]
# ID: 6, Bounding Box: [571, 284, 654, 369]
# ID: 5, Bounding Box: [477, 210, 525, 250]
# ID: 4, Bounding Box: [270, 358, 375, 448]
#
# 0: 384x640 5 cars, 78.8ms
# Speed: 3.0ms preprocess, 78.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 7, Bounding Box: [568, 204, 608, 240]
# ID: 6, Bounding Box: [557, 302, 643, 393]
# ID: 5, Bounding Box: [471, 215, 520, 256]
# ID: 4, Bounding Box: [240, 378, 354, 473]
#
# 0: 384x640 6 cars, 82.8ms
# Speed: 2.0ms preprocess, 82.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 7, Bounding Box: [566, 212, 605, 248]
# ID: 6, Bounding Box: [542, 324, 632, 423]
# ID: 5, Bounding Box: [464, 221, 515, 264]
# ID: 4, Bounding Box: [199, 394, 326, 487]
#
# 0: 384x640 7 cars, 80.3ms
# Speed: 3.5ms preprocess, 80.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 8, Bounding Box: [624, 193, 659, 254]
# ID: 7, Bounding Box: [560, 220, 600, 257]
# ID: 6, Bounding Box: [526, 348, 624, 459]
# ID: 5, Bounding Box: [455, 228, 508, 272]
# ID: 4, Bounding Box: [176, 412, 306, 494]
#
# 0: 384x640 5 cars, 95.5ms
# Speed: 2.9ms preprocess, 95.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# ID: 8, Bounding Box: [621, 200, 658, 265]
# ID: 7, Bounding Box: [554, 227, 597, 267]
# ID: 6, Bounding Box: [509, 371, 613, 481]
# ID: 5, Bounding Box: [446, 233, 502, 281]
#
# 0: 384x640 5 cars, 78.8ms
# Speed: 4.0ms preprocess, 78.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 8, Bounding Box: [617, 209, 658, 278]
# ID: 7, Bounding Box: [548, 234, 593, 276]
# ID: 9, Bounding Box: [558, 183, 597, 213]
# ID: 6, Bounding Box: [496, 396, 603, 493]
# ID: 5, Bounding Box: [436, 241, 494, 290]
#
# 0: 384x640 1 person, 5 cars, 87.8ms
# Speed: 2.5ms preprocess, 87.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# ID: 8, Bounding Box: [613, 223, 659, 294]
# ID: 7, Bounding Box: [539, 242, 588, 287]
# ID: 5, Bounding Box: [425, 248, 487, 300]
#
# 0: 384x640 4 cars, 79.8ms
# Speed: 2.0ms preprocess, 79.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 8, Bounding Box: [607, 231, 659, 309]
# ID: 7, Bounding Box: [532, 252, 583, 300]
# ID: 5, Bounding Box: [412, 258, 477, 312]
#
# 0: 384x640 4 cars, 84.7ms
# Speed: 2.0ms preprocess, 84.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 8, Bounding Box: [599, 242, 656, 328]
# ID: 7, Bounding Box: [524, 262, 578, 313]
# ID: 10, Bounding Box: [549, 196, 590, 234]
# ID: 5, Bounding Box: [397, 268, 465, 325]
#
# 0: 384x640 1 person, 4 cars, 82.8ms
# Speed: 2.5ms preprocess, 82.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 8, Bounding Box: [592, 255, 656, 349]
# ID: 7, Bounding Box: [514, 273, 572, 328]
# ID: 10, Bounding Box: [544, 201, 587, 238]
# ID: 5, Bounding Box: [380, 281, 454, 341]
#
# 0: 384x640 5 cars, 75.7ms
# Speed: 2.0ms preprocess, 75.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 8, Bounding Box: [582, 271, 654, 375]
# ID: 7, Bounding Box: [503, 287, 565, 346]
# ID: 10, Bounding Box: [539, 206, 583, 245]
# ID: 5, Bounding Box: [361, 294, 440, 359]
#
# 0: 384x640 6 cars, 78.7ms
# Speed: 3.0ms preprocess, 78.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 8, Bounding Box: [572, 290, 652, 404]
# ID: 7, Bounding Box: [490, 302, 557, 366]
# ID: 10, Bounding Box: [535, 212, 580, 253]
# ID: 5, Bounding Box: [339, 309, 425, 378]
#
# 0: 384x640 7 cars, 73.8ms
# Speed: 2.0ms preprocess, 73.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 8, Bounding Box: [556, 314, 642, 440]
# ID: 7, Bounding Box: [477, 318, 549, 387]
# ID: 10, Bounding Box: [530, 218, 577, 261]
# ID: 5, Bounding Box: [312, 326, 406, 401]
#
# 0: 384x640 5 cars, 74.7ms
# Speed: 4.0ms preprocess, 74.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# ID: 11, Bounding Box: [504, 186, 545, 221]
# ID: 8, Bounding Box: [540, 336, 633, 471]
# ID: 7, Bounding Box: [459, 337, 538, 413]
# ID: 10, Bounding Box: [523, 226, 573, 270]
# ID: 5, Bounding Box: [281, 347, 385, 428]
#
# 0: 384x640 4 cars, 88.3ms
# Speed: 2.0ms preprocess, 88.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 11, Bounding Box: [499, 190, 542, 227]
# ID: 7, Bounding Box: [439, 359, 525, 443]
# ID: 10, Bounding Box: [517, 234, 569, 281]
# ID: 5, Bounding Box: [247, 370, 361, 457]
#
# 0: 384x640 4 cars, 76.3ms
# Speed: 3.5ms preprocess, 76.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 11, Bounding Box: [497, 195, 540, 233]
# ID: 7, Bounding Box: [416, 382, 510, 471]
# ID: 10, Bounding Box: [509, 242, 563, 291]
# ID: 5, Bounding Box: [204, 393, 330, 479]
#
# 0: 384x640 4 cars, 81.3ms
# Speed: 2.0ms preprocess, 81.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 11, Bounding Box: [493, 202, 534, 239]
# ID: 7, Bounding Box: [393, 406, 495, 487]
# ID: 10, Bounding Box: [500, 252, 558, 304]
# ID: 5, Bounding Box: [177, 417, 304, 492]
# 0: 384x640 2 cars, 73.3ms
# Speed: 5.0ms preprocess, 73.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# ID: 11, Bounding Box: [487, 209, 530, 246]
# ID: 10, Bounding Box: [491, 261, 553, 316]
#
# 0: 384x640 2 cars, 77.3ms
# Speed: 1.5ms preprocess, 77.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 11, Bounding Box: [480, 214, 524, 253]
# ID: 10, Bounding Box: [480, 271, 546, 330]
#
# 0: 384x640 2 cars, 72.7ms
# Speed: 2.5ms preprocess, 72.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 11, Bounding Box: [472, 221, 517, 261]
# ID: 10, Bounding Box: [468, 284, 538, 347]
#
# 0: 384x640 2 cars, 72.7ms
# Speed: 2.0ms preprocess, 72.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 11, Bounding Box: [463, 230, 510, 270]
# ID: 10, Bounding Box: [454, 298, 530, 367]
#
# 0: 384x640 3 cars, 77.2ms
# Speed: 2.0ms preprocess, 77.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 11, Bounding Box: [453, 237, 503, 280]
# ID: 10, Bounding Box: [438, 312, 520, 386]
#
# 0: 384x640 3 cars, 77.2ms
# Speed: 6.0ms preprocess, 77.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 11, Bounding Box: [442, 245, 494, 290]
# ID: 10, Bounding Box: [421, 330, 509, 411]
#
# 0: 384x640 3 cars, 75.7ms
# Speed: 1.0ms preprocess, 75.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 11, Bounding Box: [430, 254, 487, 301]
# ID: 10, Bounding Box: [400, 351, 496, 440]
#
# 0: 384x640 5 cars, 77.3ms
# Speed: 2.5ms preprocess, 77.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# ID: 11, Bounding Box: [416, 265, 476, 314]
# ID: 10, Bounding Box: [376, 370, 480, 466]
#
# 0: 384x640 5 cars, 73.8ms
# Speed: 2.0ms preprocess, 73.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 11, Bounding Box: [400, 275, 464, 328]
# ID: 10, Bounding Box: [351, 390, 462, 481]
#
# 0: 384x640 5 cars, 79.2ms
# Speed: 2.0ms preprocess, 79.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 12, Bounding Box: [616, 207, 654, 251]
# ID: 13, Bounding Box: [514, 182, 546, 207]
# ID: 11, Bounding Box: [383, 286, 452, 342]
# ID: 10, Bounding Box: [328, 412, 445, 491]
#
# 0: 384x640 3 cars, 101.4ms
# Speed: 2.5ms preprocess, 101.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 12, Bounding Box: [615, 213, 655, 259]
# ID: 13, Bounding Box: [514, 183, 546, 209]
# ID: 11, Bounding Box: [362, 301, 437, 360]
#
# 0: 384x640 3 cars, 94.9ms
# Speed: 3.0ms preprocess, 94.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 12, Bounding Box: [611, 222, 656, 272]
# ID: 11, Bounding Box: [340, 316, 420, 379]
#
# 0: 384x640 3 cars, 88.4ms
# Speed: 3.0ms preprocess, 88.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 12, Bounding Box: [607, 232, 654, 284]
# ID: 11, Bounding Box: [315, 333, 402, 401]
#
# 0: 384x640 4 cars, 79.7ms
# Speed: 2.0ms preprocess, 79.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 14, Bounding Box: [508, 186, 545, 217]
# ID: 12, Bounding Box: [602, 241, 655, 298]
# ID: 11, Bounding Box: [284, 354, 379, 428]
#
# 0: 384x640 4 cars, 152.9ms
# Speed: 2.5ms preprocess, 152.9ms inference, 24.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 14, Bounding Box: [506, 186, 544, 220]
# ID: 12, Bounding Box: [595, 253, 650, 315]
# ID: 11, Bounding Box: [250, 378, 353, 458]
#
# 0: 384x640 4 cars, 102.9ms
# Speed: 2.5ms preprocess, 102.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 14, Bounding Box: [504, 189, 542, 224]
# ID: 12, Bounding Box: [589, 266, 647, 332]
# ID: 11, Bounding Box: [205, 401, 321, 480]
#
# 0: 384x640 2 cars, 77.3ms
# Speed: 1.0ms preprocess, 77.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 14, Bounding Box: [502, 194, 540, 228]
# ID: 12, Bounding Box: [580, 282, 643, 355]
#
# 0: 384x640 3 cars, 74.7ms
# Speed: 3.0ms preprocess, 74.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 14, Bounding Box: [501, 198, 538, 230]
# ID: 12, Bounding Box: [571, 301, 638, 380]
#
# 0: 384x640 3 cars, 80.2ms
# Speed: 2.0ms preprocess, 80.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 14, Bounding Box: [499, 201, 537, 234]
# ID: 12, Bounding Box: [560, 322, 631, 410]
#
# 0: 384x640 3 cars, 76.8ms
# Speed: 4.0ms preprocess, 76.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 15, Bounding Box: [617, 210, 656, 253]
# ID: 14, Bounding Box: [498, 204, 536, 238]
# ID: 12, Bounding Box: [547, 347, 625, 445]
#
# 0: 384x640 3 cars, 153.4ms
# Speed: 7.5ms preprocess, 153.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 15, Bounding Box: [616, 216, 656, 261]
# ID: 14, Bounding Box: [496, 206, 534, 241]
# ID: 12, Bounding Box: [533, 373, 615, 473]
#
# 0: 384x640 5 cars, 77.8ms
# Speed: 2.0ms preprocess, 77.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 15, Bounding Box: [615, 225, 658, 271]
# ID: 14, Bounding Box: [493, 211, 531, 245]
# ID: 12, Bounding Box: [521, 401, 606, 489]
#
# 0: 384x640 4 cars, 79.3ms
# Speed: 2.0ms preprocess, 79.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 15, Bounding Box: [611, 233, 658, 283]
# ID: 14, Bounding Box: [490, 213, 528, 248]
#
# 0: 384x640 5 cars, 75.9ms
# Speed: 2.5ms preprocess, 75.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 15, Bounding Box: [606, 240, 658, 295]
# ID: 14, Bounding Box: [487, 216, 526, 252]
#
# 0: 384x640 5 cars, 85.3ms
# Speed: 2.0ms preprocess, 85.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 16, Bounding Box: [502, 182, 546, 211]
# ID: 17, Bounding Box: [575, 186, 616, 221]
# ID: 15, Bounding Box: [601, 250, 656, 308]
# ID: 14, Bounding Box: [483, 220, 523, 258]
#
# 0: 384x640 5 cars, 72.7ms
# Speed: 2.0ms preprocess, 72.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 16, Bounding Box: [500, 183, 547, 213]
# ID: 17, Bounding Box: [572, 190, 613, 226]
# ID: 15, Bounding Box: [593, 261, 651, 323]
# ID: 14, Bounding Box: [479, 224, 520, 262]
#
# 0: 384x640 5 cars, 131.0ms
# Speed: 27.1ms preprocess, 131.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# ID: 18, Bounding Box: [623, 223, 658, 266]
# ID: 16, Bounding Box: [499, 183, 547, 215]
# ID: 17, Bounding Box: [567, 196, 610, 234]
# ID: 15, Bounding Box: [588, 274, 650, 341]
# ID: 14, Bounding Box: [474, 228, 517, 268]
#
# 0: 384x640 5 cars, 77.0ms
# Speed: 2.5ms preprocess, 77.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 18, Bounding Box: [619, 224, 660, 274]
# ID: 16, Bounding Box: [499, 184, 547, 218]
# ID: 17, Bounding Box: [563, 200, 608, 241]
# ID: 15, Bounding Box: [580, 287, 648, 361]
# ID: 14, Bounding Box: [470, 233, 514, 273]
#
# 0: 384x640 5 cars, 85.3ms
# Speed: 2.0ms preprocess, 85.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 18, Bounding Box: [616, 231, 661, 287]
# ID: 16, Bounding Box: [500, 189, 546, 222]
# ID: 17, Bounding Box: [558, 207, 605, 249]
# ID: 15, Bounding Box: [570, 304, 641, 383]
# ID: 14, Bounding Box: [464, 239, 510, 280]
#
# 0: 384x640 7 cars, 80.7ms
# Speed: 2.5ms preprocess, 80.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 18, Bounding Box: [611, 236, 662, 299]
# ID: 16, Bounding Box: [501, 192, 546, 224]
# ID: 17, Bounding Box: [553, 213, 601, 257]
# ID: 15, Bounding Box: [559, 323, 634, 409]
# ID: 14, Bounding Box: [457, 243, 505, 287]
#
# 0: 384x640 7 cars, 84.3ms
# Speed: 2.0ms preprocess, 84.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 18, Bounding Box: [607, 244, 663, 310]
# ID: 16, Bounding Box: [502, 195, 545, 227]
# ID: 17, Bounding Box: [546, 221, 597, 267]
# ID: 15, Bounding Box: [546, 345, 628, 440]
# ID: 14, Bounding Box: [452, 248, 501, 292]
#
# 0: 384x640 7 cars, 74.8ms
# Speed: 2.5ms preprocess, 74.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 18, Bounding Box: [602, 253, 661, 324]
# ID: 16, Bounding Box: [500, 197, 542, 230]
# ID: 17, Bounding Box: [540, 228, 592, 277]
# ID: 15, Bounding Box: [530, 366, 618, 468]
# ID: 14, Bounding Box: [443, 253, 495, 300]
#
# 0: 384x640 7 cars, 79.8ms
# Speed: 1.0ms preprocess, 79.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 18, Bounding Box: [596, 263, 661, 338]
# ID: 16, Bounding Box: [499, 200, 541, 234]
# ID: 17, Bounding Box: [533, 236, 588, 287]
# ID: 15, Bounding Box: [517, 390, 612, 485]
# ID: 14, Bounding Box: [435, 259, 489, 307]
# 0: 384x640 8 cars, 79.8ms
# Speed: 2.5ms preprocess, 79.8ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# ID: 19, Bounding Box: [583, 199, 618, 227]
# ID: 18, Bounding Box: [589, 276, 659, 356]
# ID: 16, Bounding Box: [497, 204, 539, 238]
# ID: 17, Bounding Box: [524, 245, 582, 300]
# ID: 15, Bounding Box: [502, 419, 604, 494]
# ID: 14, Bounding Box: [426, 266, 483, 316]
#
# 0: 384x640 5 cars, 73.8ms
# Speed: 2.0ms preprocess, 73.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 19, Bounding Box: [580, 207, 614, 234]
# ID: 18, Bounding Box: [580, 291, 656, 378]
# ID: 16, Bounding Box: [495, 206, 537, 241]
# ID: 17, Bounding Box: [513, 255, 574, 314]
# ID: 14, Bounding Box: [415, 273, 475, 326]
#
# 0: 384x640 6 cars, 81.7ms
# Speed: 2.3ms preprocess, 81.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 19, Bounding Box: [575, 209, 614, 240]
# ID: 18, Bounding Box: [572, 307, 656, 402]
# ID: 16, Bounding Box: [491, 210, 533, 245]
# ID: 17, Bounding Box: [502, 266, 567, 330]
# ID: 14, Bounding Box: [402, 281, 465, 335]
#
# 0: 384x640 7 cars, 109.4ms
# Speed: 2.5ms preprocess, 109.4ms inference, 4.5ms postprocess per image at shape (1, 3, 384, 640)
# ID: 19, Bounding Box: [571, 213, 611, 247]
# ID: 18, Bounding Box: [557, 328, 643, 430]
# ID: 16, Bounding Box: [488, 214, 530, 249]
# ID: 17, Bounding Box: [489, 280, 558, 347]
# ID: 14, Bounding Box: [390, 290, 456, 346]
#
# 0: 384x640 6 cars, 99.9ms
# Speed: 2.0ms preprocess, 99.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 19, Bounding Box: [566, 219, 609, 255]
# ID: 18, Bounding Box: [541, 360, 631, 464]
# ID: 16, Bounding Box: [485, 217, 528, 253]
# ID: 17, Bounding Box: [474, 294, 549, 368]
# ID: 14, Bounding Box: [375, 300, 446, 360]
#
# 0: 384x640 8 cars, 94.3ms
# Speed: 2.0ms preprocess, 94.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# ID: 20, Bounding Box: [620, 210, 660, 254]
# ID: 19, Bounding Box: [561, 225, 605, 264]
# ID: 18, Bounding Box: [528, 375, 624, 482]
# ID: 16, Bounding Box: [481, 221, 525, 259]
# ID: 17, Bounding Box: [454, 311, 536, 392]
# ID: 14, Bounding Box: [358, 311, 434, 374]
#
# 0: 384x640 7 cars, 73.7ms
# Speed: 2.0ms preprocess, 73.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 20, Bounding Box: [618, 219, 659, 264]
# ID: 19, Bounding Box: [554, 232, 601, 274]
# ID: 18, Bounding Box: [519, 397, 618, 493]
# ID: 16, Bounding Box: [475, 225, 522, 264]
# ID: 17, Bounding Box: [433, 331, 522, 420]
# ID: 14, Bounding Box: [341, 321, 420, 389]
#
# 0: 384x640 7 cars, 77.2ms
# Speed: 2.0ms preprocess, 77.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 20, Bounding Box: [616, 225, 659, 272]
# ID: 19, Bounding Box: [548, 240, 597, 285]
# ID: 16, Bounding Box: [470, 230, 518, 270]
# ID: 17, Bounding Box: [404, 357, 503, 455]
# ID: 14, Bounding Box: [321, 335, 406, 406]
#
# 0: 384x640 7 cars, 74.2ms
# Speed: 3.0ms preprocess, 74.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 20, Bounding Box: [612, 233, 658, 283]
# ID: 19, Bounding Box: [540, 250, 593, 297]
# ID: 16, Bounding Box: [465, 235, 514, 275]
# ID: 17, Bounding Box: [374, 380, 482, 477]
# ID: 21, Bounding Box: [518, 180, 550, 203]
# ID: 14, Bounding Box: [299, 350, 390, 427]
#
# 0: 384x640 7 cars, 81.8ms
# Speed: 2.0ms preprocess, 81.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 20, Bounding Box: [607, 239, 657, 293]
# ID: 19, Bounding Box: [531, 261, 586, 312]
# ID: 16, Bounding Box: [458, 240, 509, 281]
# ID: 17, Bounding Box: [342, 405, 460, 489]
# ID: 21, Bounding Box: [518, 180, 551, 204]
# ID: 14, Bounding Box: [274, 365, 372, 448]
#
# 0: 384x640 7 cars, 74.8ms
# Speed: 2.0ms preprocess, 74.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 20, Bounding Box: [602, 248, 656, 305]
# ID: 19, Bounding Box: [522, 273, 580, 327]
# ID: 16, Bounding Box: [451, 245, 504, 288]
# ID: 21, Bounding Box: [521, 181, 553, 206]
# ID: 14, Bounding Box: [245, 383, 350, 470]
#
# 0: 384x640 6 cars, 78.7ms
# Speed: 2.0ms preprocess, 78.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 22, Bounding Box: [574, 194, 608, 223]
# ID: 20, Bounding Box: [595, 258, 653, 319]
# ID: 19, Bounding Box: [510, 287, 573, 345]
# ID: 16, Bounding Box: [442, 251, 499, 296]
# ID: 21, Bounding Box: [521, 182, 554, 207]
# ID: 14, Bounding Box: [205, 399, 323, 482]
#
# 0: 384x640 6 cars, 75.7ms
# Speed: 1.5ms preprocess, 75.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 22, Bounding Box: [570, 201, 606, 229]
# ID: 20, Bounding Box: [588, 270, 649, 334]
# ID: 19, Bounding Box: [496, 302, 565, 365]
# ID: 16, Bounding Box: [434, 259, 493, 305]
# ID: 21, Bounding Box: [523, 183, 554, 209]
#
# 0: 384x640 6 cars, 74.7ms
# Speed: 3.0ms preprocess, 74.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# ID: 22, Bounding Box: [565, 206, 604, 236]
# ID: 20, Bounding Box: [579, 283, 645, 354]
# ID: 19, Bounding Box: [480, 320, 555, 388]
# ID: 16, Bounding Box: [425, 266, 487, 314]
# ID: 21, Bounding Box: [522, 184, 555, 211]
#
# 0: 384x640 5 cars, 1 truck, 77.2ms
# Speed: 1.5ms preprocess, 77.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# ID: 22, Bounding Box: [561, 208, 602, 241]
# ID: 20, Bounding Box: [570, 299, 640, 378]
# ID: 19, Bounding Box: [460, 342, 542, 417]
# ID: 16, Bounding Box: [414, 275, 479, 326]
#
# 0: 384x640 7 cars, 77.2ms
# Speed: 2.0ms preprocess, 77.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 23, Bounding Box: [518, 186, 562, 219]
# ID: 22, Bounding Box: [557, 212, 600, 247]
# ID: 20, Bounding Box: [559, 316, 633, 404]
# ID: 19, Bounding Box: [438, 367, 529, 450]
# ID: 16, Bounding Box: [401, 283, 470, 337]
#
# 0: 384x640 5 cars, 1 truck, 74.7ms
# Speed: 3.0ms preprocess, 74.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 23, Bounding Box: [521, 188, 563, 222]
# ID: 22, Bounding Box: [552, 219, 596, 255]
# ID: 20, Bounding Box: [547, 337, 627, 435]
# ID: 19, Bounding Box: [413, 394, 512, 477]
# ID: 16, Bounding Box: [387, 294, 460, 349]
#
# 0: 384x640 6 cars, 76.8ms
# Speed: 1.0ms preprocess, 76.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 23, Bounding Box: [520, 189, 562, 225]
# ID: 22, Bounding Box: [547, 227, 592, 264]
# ID: 20, Bounding Box: [534, 360, 622, 466]
# ID: 19, Bounding Box: [390, 424, 496, 491]
# ID: 16, Bounding Box: [371, 305, 448, 364]
#
# 0: 384x640 6 cars, 73.2ms
# Speed: 3.0ms preprocess, 73.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 23, Bounding Box: [519, 192, 560, 230]
# ID: 22, Bounding Box: [541, 234, 589, 272]
# ID: 20, Bounding Box: [518, 381, 613, 483]
# ID: 16, Bounding Box: [353, 317, 436, 380]
#
# 0: 384x640 8 cars, 90.3ms
# Speed: 3.0ms preprocess, 90.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 23, Bounding Box: [519, 195, 559, 232]
# ID: 22, Bounding Box: [535, 241, 584, 281]
# ID: 20, Bounding Box: [504, 407, 602, 493]
# ID: 16, Bounding Box: [335, 330, 422, 399]
#
# 0: 384x640 7 cars, 80.8ms
# Speed: 2.0ms preprocess, 80.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 24, Bounding Box: [623, 258, 664, 309]
# ID: 25, Bounding Box: [630, 184, 673, 220]
# ID: 23, Bounding Box: [516, 197, 557, 235]
# ID: 22, Bounding Box: [527, 249, 579, 292]
# ID: 16, Bounding Box: [313, 346, 407, 420]
#
# 0: 384x640 8 cars, 84.3ms
# Speed: 3.0ms preprocess, 84.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 24, Bounding Box: [618, 270, 663, 323]
# ID: 25, Bounding Box: [629, 184, 675, 224]
# ID: 23, Bounding Box: [513, 201, 555, 238]
# ID: 22, Bounding Box: [518, 258, 573, 303]
# ID: 16, Bounding Box: [286, 364, 388, 444]
#
# 0: 384x640 7 cars, 86.3ms
# Speed: 2.0ms preprocess, 86.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 26, Bounding Box: [582, 193, 615, 222]
# ID: 24, Bounding Box: [611, 283, 661, 339]
# ID: 23, Bounding Box: [510, 203, 553, 241]
# ID: 22, Bounding Box: [508, 268, 565, 316]
# ID: 16, Bounding Box: [255, 383, 367, 468]
#
# 0: 384x640 6 cars, 78.7ms
# Speed: 2.0ms preprocess, 78.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 26, Bounding Box: [579, 197, 614, 227]
# ID: 24, Bounding Box: [603, 298, 659, 358]
# ID: 23, Bounding Box: [507, 205, 551, 244]
# ID: 22, Bounding Box: [497, 280, 557, 331]
# ID: 16, Bounding Box: [210, 401, 338, 483]
# 0: 384x640 6 cars, 81.3ms
# Speed: 2.5ms preprocess, 81.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 27, Bounding Box: [622, 214, 659, 246]
# ID: 26, Bounding Box: [575, 204, 611, 235]
# ID: 24, Bounding Box: [596, 314, 659, 380]
# ID: 23, Bounding Box: [504, 206, 550, 247]
# ID: 22, Bounding Box: [484, 294, 548, 349]
# ID: 16, Bounding Box: [185, 420, 319, 491]
#
# 0: 384x640 5 cars, 83.8ms
# Speed: 3.0ms preprocess, 83.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 27, Bounding Box: [619, 221, 659, 256]
# ID: 26, Bounding Box: [570, 208, 609, 241]
# ID: 24, Bounding Box: [585, 334, 653, 406]
# ID: 23, Bounding Box: [501, 209, 548, 252]
# ID: 22, Bounding Box: [469, 309, 538, 367]
#
# 0: 384x640 5 cars, 82.3ms
# Speed: 2.0ms preprocess, 82.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 27, Bounding Box: [617, 224, 659, 262]
# ID: 26, Bounding Box: [566, 212, 605, 246]
# ID: 24, Bounding Box: [572, 356, 643, 436]
# ID: 23, Bounding Box: [496, 211, 545, 256]
# ID: 22, Bounding Box: [452, 326, 526, 388]
#
# 0: 384x640 5 cars, 82.3ms
# Speed: 4.5ms preprocess, 82.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 27, Bounding Box: [615, 231, 660, 272]
# ID: 26, Bounding Box: [560, 218, 602, 254]
# ID: 24, Bounding Box: [557, 383, 633, 469]
# ID: 23, Bounding Box: [492, 214, 542, 261]
# ID: 22, Bounding Box: [432, 344, 513, 413]
#
# 0: 384x640 5 cars, 93.3ms
# Speed: 2.0ms preprocess, 93.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 27, Bounding Box: [611, 241, 660, 284]
# ID: 26, Bounding Box: [555, 224, 599, 262]
# ID: 24, Bounding Box: [541, 409, 624, 487]
# ID: 23, Bounding Box: [486, 218, 538, 265]
# ID: 22, Bounding Box: [408, 369, 495, 445]
#
# 0: 384x640 4 cars, 88.4ms
# Speed: 2.0ms preprocess, 88.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 27, Bounding Box: [606, 250, 658, 297]
# ID: 26, Bounding Box: [549, 231, 594, 270]
# ID: 23, Bounding Box: [481, 222, 534, 269]
# ID: 22, Bounding Box: [381, 392, 477, 471]
#
# 0: 384x640 5 cars, 80.7ms
# Speed: 3.5ms preprocess, 80.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 27, Bounding Box: [600, 261, 655, 310]
# ID: 26, Bounding Box: [541, 239, 588, 279]
# ID: 23, Bounding Box: [475, 226, 530, 274]
# ID: 22, Bounding Box: [355, 416, 459, 486]
#
# 0: 384x640 4 cars, 83.8ms
# Speed: 2.5ms preprocess, 83.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 27, Bounding Box: [594, 274, 652, 326]
# ID: 26, Bounding Box: [534, 246, 583, 289]
# ID: 23, Bounding Box: [468, 230, 525, 279]
#
# 0: 384x640 5 cars, 79.2ms
# Speed: 2.5ms preprocess, 79.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 27, Bounding Box: [586, 287, 647, 342]
# ID: 26, Bounding Box: [525, 254, 578, 300]
# ID: 23, Bounding Box: [462, 234, 521, 286]
#
# 0: 384x640 5 cars, 91.2ms
# Speed: 3.5ms preprocess, 91.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 28, Bounding Box: [622, 262, 667, 312]
# ID: 27, Bounding Box: [577, 304, 643, 364]
# ID: 26, Bounding Box: [515, 264, 570, 312]
# ID: 23, Bounding Box: [454, 238, 515, 291]
#
# 0: 384x640 5 cars, 80.7ms
# Speed: 3.0ms preprocess, 80.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 28, Bounding Box: [617, 271, 666, 323]
# ID: 27, Bounding Box: [566, 323, 636, 388]
# ID: 26, Bounding Box: [502, 276, 563, 327]
# ID: 23, Bounding Box: [446, 243, 510, 298]
#
# 0: 384x640 5 cars, 82.8ms
# Speed: 2.0ms preprocess, 82.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 28, Bounding Box: [610, 285, 663, 341]
# ID: 27, Bounding Box: [555, 346, 630, 417]
# ID: 26, Bounding Box: [491, 288, 555, 343]
# ID: 23, Bounding Box: [438, 250, 504, 307]
#
# 0: 384x640 7 cars, 80.7ms
# Speed: 2.0ms preprocess, 80.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 29, Bounding Box: [517, 195, 552, 220]
# ID: 28, Bounding Box: [604, 301, 665, 364]
# ID: 27, Bounding Box: [540, 373, 625, 453]
# ID: 26, Bounding Box: [476, 301, 545, 361]
# ID: 23, Bounding Box: [428, 256, 497, 318]
#
# 0: 384x640 8 cars, 81.8ms
# Speed: 3.0ms preprocess, 81.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 29, Bounding Box: [516, 198, 553, 225]
# ID: 28, Bounding Box: [595, 318, 663, 387]
# ID: 27, Bounding Box: [523, 399, 614, 478]
# ID: 26, Bounding Box: [460, 317, 535, 382]
# ID: 23, Bounding Box: [418, 263, 491, 328]
#
# 0: 384x640 7 cars, 81.8ms
# Speed: 2.5ms preprocess, 81.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 29, Bounding Box: [516, 199, 552, 226]
# ID: 28, Bounding Box: [582, 341, 655, 416]
# ID: 27, Bounding Box: [506, 429, 604, 491]
# ID: 26, Bounding Box: [441, 336, 524, 406]
# ID: 23, Bounding Box: [406, 270, 482, 337]
#
# 0: 384x640 7 cars, 80.8ms
# Speed: 4.0ms preprocess, 80.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 30, Bounding Box: [621, 255, 666, 300]
# ID: 29, Bounding Box: [515, 202, 552, 229]
# ID: 28, Bounding Box: [569, 365, 646, 447]
# ID: 26, Bounding Box: [418, 357, 509, 436]
# ID: 23, Bounding Box: [394, 276, 473, 347]
#
# 0: 384x640 6 cars, 1 truck, 84.8ms
# Speed: 2.5ms preprocess, 84.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 30, Bounding Box: [617, 265, 665, 313]
# ID: 29, Bounding Box: [514, 204, 551, 232]
# ID: 28, Bounding Box: [552, 392, 635, 476]
# ID: 26, Bounding Box: [391, 381, 491, 466]
# ID: 23, Bounding Box: [379, 285, 463, 359]
#
# 0: 384x640 7 cars, 81.3ms
# Speed: 2.0ms preprocess, 81.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 30, Bounding Box: [613, 278, 665, 329]
# ID: 29, Bounding Box: [512, 207, 550, 235]
# ID: 28, Bounding Box: [542, 421, 628, 492]
# ID: 26, Bounding Box: [366, 404, 472, 484]
# ID: 23, Bounding Box: [365, 294, 452, 373]
#
# 0: 384x640 7 cars, 84.8ms
# Speed: 5.5ms preprocess, 84.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 31, Bounding Box: [574, 198, 610, 238]
# ID: 30, Bounding Box: [606, 292, 661, 347]
# ID: 29, Bounding Box: [510, 208, 548, 238]
# ID: 23, Bounding Box: [347, 303, 441, 386]
#
# 0: 384x640 6 cars, 75.7ms
# Speed: 2.0ms preprocess, 75.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 31, Bounding Box: [570, 201, 609, 243]
# ID: 30, Bounding Box: [601, 307, 663, 368]
# ID: 29, Bounding Box: [506, 209, 547, 242]
# ID: 23, Bounding Box: [328, 315, 428, 402]
#
# 0: 384x640 7 cars, 73.3ms
# Speed: 1.5ms preprocess, 73.3ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 32, Bounding Box: [544, 182, 580, 209]
# ID: 31, Bounding Box: [565, 203, 607, 248]
# ID: 30, Bounding Box: [593, 325, 662, 394]
# ID: 29, Bounding Box: [504, 211, 545, 245]
# ID: 23, Bounding Box: [308, 327, 414, 421]
#
# 0: 384x640 7 cars, 73.7ms
# Speed: 2.5ms preprocess, 73.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 31, Bounding Box: [561, 207, 606, 255]
# ID: 30, Bounding Box: [580, 348, 653, 422]
# ID: 29, Bounding Box: [502, 214, 543, 249]
# ID: 23, Bounding Box: [285, 341, 400, 442]
#
# 0: 384x640 7 cars, 75.2ms
# Speed: 2.0ms preprocess, 75.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 33, Bounding Box: [631, 249, 670, 304]
# ID: 31, Bounding Box: [557, 210, 606, 261]
# ID: 30, Bounding Box: [568, 376, 643, 456]
# ID: 29, Bounding Box: [499, 218, 541, 254]
# ID: 23, Bounding Box: [258, 356, 381, 463]
#
# 0: 384x640 7 cars, 95.3ms
# Speed: 2.0ms preprocess, 95.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 34, Bounding Box: [593, 182, 629, 214]
# ID: 33, Bounding Box: [626, 259, 669, 317]
# ID: 31, Bounding Box: [552, 215, 604, 269]
# ID: 30, Bounding Box: [556, 402, 634, 481]
# ID: 29, Bounding Box: [495, 221, 537, 258]
# ID: 23, Bounding Box: [229, 369, 362, 478]
#
# 0: 384x640 9 cars, 73.3ms
# Speed: 3.0ms preprocess, 73.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 33, Bounding Box: [620, 272, 668, 336]
# ID: 31, Bounding Box: [544, 224, 597, 278]
# ID: 30, Bounding Box: [547, 434, 631, 493]
# ID: 29, Bounding Box: [491, 226, 533, 263]
# ID: 23, Bounding Box: [197, 384, 339, 486]
#
# 0: 384x640 10 cars, 70.8ms
# Speed: 2.0ms preprocess, 70.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 33, Bounding Box: [613, 286, 667, 354]
# ID: 31, Bounding Box: [537, 231, 591, 288]
# ID: 29, Bounding Box: [487, 230, 529, 268]
# ID: 23, Bounding Box: [177, 401, 322, 492]
# 0: 384x640 7 cars, 72.7ms
# Speed: 3.0ms preprocess, 72.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# ID: 33, Bounding Box: [606, 302, 668, 379]
# ID: 31, Bounding Box: [530, 237, 585, 296]
# ID: 29, Bounding Box: [481, 235, 526, 274]
#
# 0: 384x640 5 cars, 78.3ms
# Speed: 2.0ms preprocess, 78.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 35, Bounding Box: [557, 236, 601, 271]
# ID: 36, Bounding Box: [623, 235, 664, 279]
# ID: 33, Bounding Box: [595, 320, 663, 404]
# ID: 31, Bounding Box: [523, 244, 579, 306]
#
# 0: 384x640 7 cars, 81.8ms
# Speed: 1.5ms preprocess, 81.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 35, Bounding Box: [552, 241, 597, 279]
# ID: 36, Bounding Box: [620, 242, 664, 288]
# ID: 33, Bounding Box: [583, 342, 659, 436]
# ID: 31, Bounding Box: [514, 253, 572, 317]
#
# 0: 384x640 7 cars, 75.8ms
# Speed: 2.0ms preprocess, 75.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 35, Bounding Box: [550, 248, 594, 288]
# ID: 36, Bounding Box: [614, 252, 665, 302]
# ID: 37, Bounding Box: [459, 253, 504, 296]
# ID: 33, Bounding Box: [570, 368, 649, 469]
# ID: 31, Bounding Box: [504, 262, 566, 330]
#
# 0: 384x640 7 cars, 80.5ms
# Speed: 3.5ms preprocess, 80.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 35, Bounding Box: [542, 254, 589, 298]
# ID: 36, Bounding Box: [611, 262, 665, 314]
# ID: 37, Bounding Box: [452, 259, 502, 304]
# ID: 33, Bounding Box: [558, 392, 640, 486]
# ID: 31, Bounding Box: [492, 271, 558, 345]
#
# 0: 384x640 9 cars, 75.3ms
# Speed: 3.0ms preprocess, 75.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 38, Bounding Box: [572, 223, 613, 261]
# ID: 35, Bounding Box: [535, 262, 586, 310]
# ID: 36, Bounding Box: [604, 273, 662, 329]
# ID: 37, Bounding Box: [442, 265, 495, 312]
# ID: 33, Bounding Box: [548, 425, 637, 496]
# ID: 32, Bounding Box: [500, 211, 546, 257]
# ID: 31, Bounding Box: [478, 281, 549, 360]
#
# 0: 384x640 9 cars, 74.3ms
# Speed: 3.0ms preprocess, 74.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# ID: 38, Bounding Box: [568, 230, 609, 269]
# ID: 35, Bounding Box: [527, 271, 582, 321]
# ID: 36, Bounding Box: [598, 287, 658, 347]
# ID: 37, Bounding Box: [431, 271, 487, 320]
# ID: 32, Bounding Box: [494, 215, 542, 263]
# ID: 31, Bounding Box: [463, 295, 539, 380]
#
# 0: 384x640 8 cars, 80.2ms
# Speed: 4.0ms preprocess, 80.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 38, Bounding Box: [564, 236, 607, 277]
# ID: 35, Bounding Box: [517, 281, 576, 335]
# ID: 36, Bounding Box: [590, 301, 654, 365]
# ID: 37, Bounding Box: [420, 279, 479, 332]
# ID: 34, Bounding Box: [564, 194, 597, 225]
# ID: 32, Bounding Box: [488, 220, 537, 271]
# ID: 31, Bounding Box: [446, 309, 529, 402]
#
# 0: 384x640 9 cars, 71.7ms
# Speed: 3.0ms preprocess, 71.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 38, Bounding Box: [558, 243, 604, 286]
# ID: 35, Bounding Box: [505, 291, 569, 349]
# ID: 36, Bounding Box: [580, 319, 649, 389]
# ID: 37, Bounding Box: [407, 287, 470, 344]
# ID: 34, Bounding Box: [558, 200, 593, 233]
# ID: 32, Bounding Box: [480, 224, 530, 277]
# ID: 31, Bounding Box: [426, 325, 516, 427]
#
# 0: 384x640 8 cars, 77.7ms
# Speed: 1.5ms preprocess, 77.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 38, Bounding Box: [552, 249, 600, 294]
# ID: 35, Bounding Box: [494, 303, 564, 367]
# ID: 36, Bounding Box: [570, 340, 641, 416]
# ID: 37, Bounding Box: [394, 295, 461, 356]
# ID: 34, Bounding Box: [552, 205, 588, 238]
# ID: 32, Bounding Box: [473, 230, 525, 285]
# ID: 31, Bounding Box: [400, 344, 499, 454]
#
# 0: 384x640 10 cars, 71.9ms
# Speed: 1.0ms preprocess, 71.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# ID: 39, Bounding Box: [634, 204, 670, 239]
# ID: 38, Bounding Box: [546, 258, 595, 304]
# ID: 35, Bounding Box: [481, 318, 556, 386]
# ID: 36, Bounding Box: [554, 367, 634, 450]
# ID: 37, Bounding Box: [377, 305, 449, 368]
# ID: 34, Bounding Box: [546, 208, 583, 241]
# ID: 32, Bounding Box: [464, 235, 519, 294]
# ID: 31, Bounding Box: [373, 362, 481, 476]
#
# 0: 384x640 9 cars, 73.2ms
# Speed: 3.0ms preprocess, 73.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 39, Bounding Box: [631, 210, 667, 245]
# ID: 38, Bounding Box: [538, 266, 590, 315]
# ID: 35, Bounding Box: [467, 335, 547, 408]
# ID: 37, Bounding Box: [360, 317, 437, 383]
# ID: 34, Bounding Box: [539, 212, 578, 247]
# ID: 32, Bounding Box: [455, 240, 513, 301]
# ID: 31, Bounding Box: [341, 382, 459, 488]
#
# 0: 384x640 8 cars, 76.9ms
# Speed: 2.5ms preprocess, 76.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 39, Bounding Box: [629, 213, 665, 251]
# ID: 38, Bounding Box: [528, 275, 585, 328]
# ID: 35, Bounding Box: [450, 354, 538, 433]
# ID: 37, Bounding Box: [341, 328, 424, 399]
# ID: 34, Bounding Box: [531, 216, 572, 253]
# ID: 32, Bounding Box: [446, 247, 506, 310]
#
# 0: 384x640 7 cars, 73.7ms
# Speed: 3.0ms preprocess, 73.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 39, Bounding Box: [626, 217, 665, 259]
# ID: 38, Bounding Box: [520, 285, 579, 341]
# ID: 35, Bounding Box: [431, 374, 526, 460]
# ID: 37, Bounding Box: [319, 341, 409, 418]
# ID: 34, Bounding Box: [524, 220, 566, 260]
# ID: 32, Bounding Box: [435, 252, 498, 320]
#
# 0: 384x640 9 cars, 74.8ms
# Speed: 3.0ms preprocess, 74.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# ID: 40, Bounding Box: [584, 192, 621, 224]
# ID: 39, Bounding Box: [625, 222, 664, 266]
# ID: 38, Bounding Box: [508, 296, 571, 355]
# ID: 35, Bounding Box: [409, 395, 511, 480]
# ID: 37, Bounding Box: [294, 359, 391, 442]
# ID: 34, Bounding Box: [514, 225, 560, 266]
# ID: 32, Bounding Box: [423, 260, 489, 331]
#
# 0: 384x640 10 cars, 75.2ms
# Speed: 2.5ms preprocess, 75.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 40, Bounding Box: [582, 196, 619, 228]
# ID: 39, Bounding Box: [623, 228, 665, 275]
# ID: 38, Bounding Box: [496, 310, 564, 374]
# ID: 35, Bounding Box: [384, 418, 495, 490]
# ID: 37, Bounding Box: [266, 375, 371, 465]
# ID: 34, Bounding Box: [505, 230, 552, 272]
# ID: 32, Bounding Box: [410, 268, 480, 343]
#
# 0: 384x640 9 cars, 75.2ms
# Speed: 3.0ms preprocess, 75.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 40, Bounding Box: [579, 199, 617, 233]
# ID: 39, Bounding Box: [619, 237, 665, 287]
# ID: 38, Bounding Box: [481, 325, 555, 394]
# ID: 37, Bounding Box: [235, 392, 347, 480]
# ID: 34, Bounding Box: [495, 236, 545, 280]
# ID: 32, Bounding Box: [395, 277, 469, 356]
#
# 0: 384x640 9 cars, 73.3ms
# Speed: 3.0ms preprocess, 73.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 40, Bounding Box: [575, 205, 615, 239]
# ID: 39, Bounding Box: [615, 244, 666, 299]
# ID: 38, Bounding Box: [465, 341, 545, 416]
# ID: 37, Bounding Box: [196, 412, 319, 489]
# ID: 34, Bounding Box: [483, 241, 536, 287]
# ID: 32, Bounding Box: [378, 287, 457, 370]
#
# 0: 384x640 8 cars, 74.2ms
# Speed: 2.0ms preprocess, 74.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 40, Bounding Box: [571, 209, 612, 246]
# ID: 39, Bounding Box: [610, 253, 665, 310]
# ID: 38, Bounding Box: [445, 360, 533, 442]
# ID: 34, Bounding Box: [470, 248, 525, 297]
# ID: 32, Bounding Box: [359, 299, 443, 387]
#
# 0: 384x640 8 cars, 72.7ms
# Speed: 2.0ms preprocess, 72.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 40, Bounding Box: [567, 213, 609, 252]
# ID: 39, Bounding Box: [604, 263, 664, 326]
# ID: 38, Bounding Box: [423, 380, 518, 468]
# ID: 34, Bounding Box: [457, 254, 515, 305]
# ID: 32, Bounding Box: [336, 312, 427, 405]
#
# 0: 384x640 9 cars, 73.8ms
# Speed: 2.0ms preprocess, 73.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 41, Bounding Box: [544, 180, 582, 214]
# ID: 40, Bounding Box: [562, 219, 607, 259]
# ID: 39, Bounding Box: [598, 275, 662, 342]
# ID: 38, Bounding Box: [400, 402, 502, 484]
# ID: 34, Bounding Box: [442, 262, 504, 315]
# ID: 32, Bounding Box: [311, 325, 410, 426]
#
# 0: 384x640 8 cars, 76.8ms
# Speed: 3.0ms preprocess, 76.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 42, Bounding Box: [469, 177, 528, 204]
# ID: 40, Bounding Box: [557, 224, 604, 267]
# ID: 39, Bounding Box: [590, 288, 660, 362]
# ID: 38, Bounding Box: [379, 426, 487, 493]
# ID: 34, Bounding Box: [427, 270, 492, 326]
# ID: 32, Bounding Box: [282, 340, 390, 449]
# 0: 384x640 6 cars, 1 truck, 73.2ms
# Speed: 3.0ms preprocess, 73.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 40, Bounding Box: [552, 230, 601, 274]
# ID: 39, Bounding Box: [580, 305, 656, 386]
# ID: 34, Bounding Box: [410, 278, 479, 337]
# ID: 32, Bounding Box: [250, 357, 368, 472]
#
# 0: 384x640 5 cars, 1 bus, 1 truck, 74.3ms
# Speed: 2.0ms preprocess, 74.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 40, Bounding Box: [545, 236, 596, 283]
# ID: 39, Bounding Box: [569, 323, 650, 413]
# ID: 34, Bounding Box: [391, 287, 464, 349]
# ID: 32, Bounding Box: [208, 371, 339, 484]
#
# 0: 384x640 6 cars, 74.7ms
# Speed: 2.0ms preprocess, 74.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# ID: 40, Bounding Box: [538, 243, 592, 292]
# ID: 39, Bounding Box: [552, 347, 639, 445]
# ID: 34, Bounding Box: [370, 298, 448, 365]
#
# 0: 384x640 7 cars, 75.7ms
# Speed: 2.0ms preprocess, 75.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 40, Bounding Box: [530, 250, 587, 302]
# ID: 39, Bounding Box: [539, 366, 632, 471]
# ID: 34, Bounding Box: [348, 311, 430, 381]
#
# 0: 384x640 8 cars, 81.3ms
# Speed: 3.0ms preprocess, 81.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 43, Bounding Box: [564, 213, 609, 251]
# ID: 41, Bounding Box: [517, 200, 559, 240]
# ID: 40, Bounding Box: [522, 259, 582, 314]
# ID: 39, Bounding Box: [528, 393, 627, 486]
# ID: 34, Bounding Box: [324, 323, 412, 398]
#
# 0: 384x640 8 cars, 77.3ms
# Speed: 3.0ms preprocess, 77.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 43, Bounding Box: [562, 220, 607, 258]
# ID: 41, Bounding Box: [512, 202, 556, 244]
# ID: 40, Bounding Box: [512, 268, 575, 327]
# ID: 39, Bounding Box: [520, 411, 617, 493]
# ID: 34, Bounding Box: [297, 337, 393, 418]
#
# 0: 384x640 6 cars, 74.4ms
# Speed: 3.0ms preprocess, 74.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 44, Bounding Box: [628, 230, 666, 280]
# ID: 43, Bounding Box: [560, 227, 605, 265]
# ID: 41, Bounding Box: [507, 204, 553, 250]
# ID: 40, Bounding Box: [501, 279, 569, 343]
#
# 0: 384x640 6 cars, 89.7ms
# Speed: 1.5ms preprocess, 89.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 44, Bounding Box: [626, 237, 666, 289]
# ID: 43, Bounding Box: [556, 232, 601, 271]
# ID: 41, Bounding Box: [501, 205, 548, 254]
# ID: 40, Bounding Box: [490, 290, 562, 359]
#
# 0: 384x640 7 cars, 91.3ms
# Speed: 2.0ms preprocess, 91.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 44, Bounding Box: [621, 244, 667, 300]
# ID: 43, Bounding Box: [549, 238, 595, 279]
# ID: 45, Bounding Box: [196, 381, 321, 479]
# ID: 41, Bounding Box: [494, 209, 542, 261]
# ID: 40, Bounding Box: [476, 304, 552, 378]
#
# 0: 384x640 7 cars, 96.4ms
# Speed: 2.0ms preprocess, 96.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 44, Bounding Box: [617, 252, 668, 311]
# ID: 43, Bounding Box: [543, 246, 591, 288]
# ID: 46, Bounding Box: [469, 177, 525, 205]
# ID: 41, Bounding Box: [487, 212, 538, 268]
# ID: 40, Bounding Box: [459, 318, 542, 398]
#
# 0: 384x640 6 cars, 76.2ms
# Speed: 3.0ms preprocess, 76.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 44, Bounding Box: [613, 261, 668, 323]
# ID: 43, Bounding Box: [537, 253, 587, 298]
# ID: 46, Bounding Box: [469, 177, 528, 205]
# ID: 41, Bounding Box: [479, 220, 531, 277]
# ID: 40, Bounding Box: [440, 336, 530, 423]
#
# 0: 384x640 8 cars, 74.7ms
# Speed: 2.0ms preprocess, 74.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# ID: 47, Bounding Box: [525, 180, 577, 224]
# ID: 44, Bounding Box: [606, 270, 666, 337]
# ID: 43, Bounding Box: [529, 261, 582, 308]
# ID: 46, Bounding Box: [468, 177, 529, 206]
# ID: 41, Bounding Box: [470, 226, 525, 286]
# ID: 40, Bounding Box: [418, 356, 516, 452]
#
# 0: 384x640 7 cars, 1 truck, 75.8ms
# Speed: 2.0ms preprocess, 75.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 47, Bounding Box: [522, 181, 576, 229]
# ID: 44, Bounding Box: [600, 282, 664, 353]
# ID: 43, Bounding Box: [522, 270, 576, 319]
# ID: 46, Bounding Box: [468, 177, 528, 205]
# ID: 41, Bounding Box: [461, 223, 520, 291]
# ID: 40, Bounding Box: [392, 376, 499, 475]
#
# 0: 384x640 7 cars, 1 truck, 75.2ms
# Speed: 4.5ms preprocess, 75.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 47, Bounding Box: [516, 182, 573, 233]
# ID: 44, Bounding Box: [594, 295, 663, 371]
# ID: 43, Bounding Box: [513, 281, 569, 332]
# ID: 41, Bounding Box: [450, 234, 512, 304]
# ID: 40, Bounding Box: [366, 398, 479, 488]
#
# 0: 384x640 6 cars, 1 truck, 74.3ms
# Speed: 1.0ms preprocess, 74.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 47, Bounding Box: [513, 185, 570, 238]
# ID: 44, Bounding Box: [586, 309, 662, 392]
# ID: 43, Bounding Box: [501, 294, 561, 348]
# ID: 41, Bounding Box: [439, 242, 505, 315]
# ID: 40, Bounding Box: [341, 426, 460, 497]
#
# 0: 384x640 6 cars, 1 truck, 77.8ms
# Speed: 3.0ms preprocess, 77.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 47, Bounding Box: [507, 187, 567, 243]
# ID: 44, Bounding Box: [576, 327, 657, 416]
# ID: 43, Bounding Box: [488, 308, 552, 365]
# ID: 41, Bounding Box: [427, 250, 496, 327]
#
# 0: 384x640 5 cars, 1 truck, 76.2ms
# Speed: 2.0ms preprocess, 76.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 47, Bounding Box: [503, 189, 565, 248]
# ID: 44, Bounding Box: [563, 348, 647, 444]
# ID: 43, Bounding Box: [472, 323, 542, 386]
# ID: 41, Bounding Box: [411, 258, 485, 340]
#
# 0: 384x640 7 cars, 1 truck, 73.2ms
# Speed: 2.5ms preprocess, 73.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 48, Bounding Box: [391, 268, 475, 359]
# ID: 49, Bounding Box: [586, 198, 626, 239]
# ID: 47, Bounding Box: [498, 194, 562, 255]
# ID: 44, Bounding Box: [549, 367, 639, 471]
# ID: 43, Bounding Box: [455, 341, 531, 409]
# ID: 41, Bounding Box: [398, 267, 476, 353]
#
# 0: 384x640 5 cars, 1 truck, 73.3ms
# Speed: 3.5ms preprocess, 73.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 48, Bounding Box: [373, 300, 455, 381]
# ID: 49, Bounding Box: [583, 204, 623, 245]
# ID: 47, Bounding Box: [493, 199, 558, 260]
# ID: 43, Bounding Box: [433, 361, 516, 435]
#
# 0: 384x640 5 cars, 76.8ms
# Speed: 2.0ms preprocess, 76.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ...
# ID: 52, Bounding Box: [632, 211, 666, 250]
# ID: 50, Bounding Box: [291, 256, 476, 426]
# ID: 51, Bounding Box: [616, 283, 669, 340]
# ID: 49, Bounding Box: [460, 332, 546, 435]
#
# 0: 384x640 4 cars, 1 bus, 1 truck, 76.7ms
# Speed: 2.0ms preprocess, 76.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 52, Bounding Box: [629, 220, 665, 261]
# ID: 50, Bounding Box: [264, 265, 464, 447]
# ID: 51, Bounding Box: [610, 301, 667, 362]
# ID: 49, Bounding Box: [438, 351, 532, 462]
#
# 0: 384x640 4 cars, 1 bus, 75.8ms
# Speed: 2.0ms preprocess, 75.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 52, Bounding Box: [626, 228, 666, 271]
# ID: 50, Bounding Box: [236, 274, 450, 467]
# ID: 51, Bounding Box: [602, 321, 664, 388]
# ID: 49, Bounding Box: [413, 370, 515, 480]
#
# 0: 384x640 2 cars, 1 bus, 1 truck, 77.2ms
# Speed: 2.0ms preprocess, 77.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 52, Bounding Box: [622, 237, 667, 285]
# ID: 50, Bounding Box: [196, 281, 433, 483]
# ID: 51, Bounding Box: [588, 348, 657, 423]
#
# 0: 384x640 2 cars, 1 bus, 73.2ms
# Speed: 3.0ms preprocess, 73.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 52, Bounding Box: [618, 246, 667, 298]
#
# 0: 384x640 3 cars, 72.7ms
# Speed: 2.5ms preprocess, 72.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# ID: 52, Bounding Box: [613, 258, 666, 312]
#
# 0: 384x640 3 cars, 82.8ms
# Speed: 3.5ms preprocess, 82.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 52, Bounding Box: [605, 272, 663, 331]
#
# 0: 384x640 2 cars, 73.2ms
# Speed: 3.0ms preprocess, 73.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 52, Bounding Box: [599, 289, 663, 354]
#
# 0: 384x640 2 cars, 80.7ms
# Speed: 2.0ms preprocess, 80.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 52, Bounding Box: [588, 307, 661, 381]
#
# 0: 384x640 2 cars, 74.3ms
# Speed: 3.0ms preprocess, 74.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# ID: 53, Bounding Box: [539, 199, 572, 230]
# ID: 52, Bounding Box: [575, 330, 653, 412]
#
# 0: 384x640 2 cars, 78.3ms
# Speed: 2.5ms preprocess, 78.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# ID: 53, Bounding Box: [534, 206, 567, 234]
# ID: 52, Bounding Box: [556, 357, 642, 449]
#
# 0: 384x640 1 car, 1 airplane, 78.8ms
# Speed: 3.5ms preprocess, 78.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 52, Bounding Box: [541, 385, 632, 476]
#
# 0: 384x640 2 cars, 77.8ms
# Speed: 3.0ms preprocess, 77.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 car, 68.7ms
# Speed: 1.5ms preprocess, 68.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 cars, 71.3ms
# Speed: 2.5ms preprocess, 71.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# ID: 53, Bounding Box: [513, 219, 553, 254]
#
# 0: 384x640 3 cars, 70.2ms
# Speed: 3.5ms preprocess, 70.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 53, Bounding Box: [508, 223, 548, 260]
#
# 0: 384x640 3 cars, 76.7ms
# Speed: 2.0ms preprocess, 76.7ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 53, Bounding Box: [501, 228, 544, 266]
#
# 0: 384x640 3 cars, 88.7ms
# Speed: 3.5ms preprocess, 88.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# ID: 54, Bounding Box: [529, 191, 564, 214]
# ID: 55, Bounding Box: [576, 209, 615, 252]
# ID: 53, Bounding Box: [494, 233, 538, 273]
#
# 0: 384x640 4 cars, 74.7ms
# Speed: 2.0ms preprocess, 74.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 54, Bounding Box: [530, 192, 564, 215]
# ID: 55, Bounding Box: [571, 212, 613, 259]
# ID: 53, Bounding Box: [487, 240, 532, 281]
#
# 0: 384x640 4 cars, 68.2ms
# Speed: 3.0ms preprocess, 68.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 54, Bounding Box: [530, 192, 564, 216]
# ID: 55, Bounding Box: [566, 218, 609, 268]
# ID: 53, Bounding Box: [478, 248, 526, 290]
#
# 0: 384x640 4 cars, 71.7ms
# Speed: 2.5ms preprocess, 71.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# ID: 54, Bounding Box: [529, 195, 565, 220]
# ID: 55, Bounding Box: [559, 224, 606, 278]
# ID: 53, Bounding Box: [470, 254, 520, 299]
#
# 0: 384x640 4 cars, 83.3ms
# Speed: 1.0ms preprocess, 83.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 54, Bounding Box: [528, 198, 565, 223]
# ID: 55, Bounding Box: [552, 231, 602, 289]
# ID: 53, Bounding Box: [459, 263, 512, 311]
#
# 0: 384x640 5 cars, 82.7ms
# Speed: 2.5ms preprocess, 82.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 56, Bounding Box: [629, 243, 668, 286]
# ID: 54, Bounding Box: [529, 200, 566, 226]
# ID: 55, Bounding Box: [545, 239, 597, 301]
# ID: 53, Bounding Box: [449, 271, 505, 320]
#
# 0: 384x640 4 cars, 71.2ms
# Speed: 2.0ms preprocess, 71.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 56, Bounding Box: [623, 254, 669, 301]
# ID: 54, Bounding Box: [527, 203, 566, 230]
# ID: 55, Bounding Box: [535, 248, 591, 316]
# ID: 53, Bounding Box: [435, 282, 495, 333]
#
# 0: 384x640 5 cars, 75.9ms
# Speed: 2.0ms preprocess, 75.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# ID: 56, Bounding Box: [617, 267, 668, 318]
# ID: 54, Bounding Box: [526, 205, 565, 232]
# ID: 55, Bounding Box: [526, 258, 585, 331]
# ID: 53, Bounding Box: [422, 292, 486, 346]
#
# 0: 384x640 5 cars, 78.8ms
# Speed: 1.0ms preprocess, 78.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 56, Bounding Box: [609, 282, 666, 337]
# ID: 54, Bounding Box: [525, 208, 565, 236]
# ID: 55, Bounding Box: [513, 269, 577, 348]
# ID: 53, Bounding Box: [405, 304, 475, 362]
#
# 0: 384x640 5 cars, 76.7ms
# Speed: 2.0ms preprocess, 76.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 56, Bounding Box: [602, 301, 661, 360]
# ID: 54, Bounding Box: [522, 211, 563, 241]
# ID: 55, Bounding Box: [501, 282, 569, 366]
# ID: 53, Bounding Box: [386, 317, 460, 380]
#
# 0: 384x640 6 cars, 1 truck, 79.2ms
# Speed: 3.0ms preprocess, 79.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 57, Bounding Box: [591, 191, 624, 217]
# ID: 56, Bounding Box: [590, 322, 657, 388]
# ID: 54, Bounding Box: [519, 212, 562, 244]
# ID: 55, Bounding Box: [485, 297, 559, 387]
# ID: 53, Bounding Box: [365, 334, 445, 401]
#
# 0: 384x640 5 cars, 1 truck, 77.8ms
# Speed: 4.0ms preprocess, 77.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 57, Bounding Box: [588, 196, 624, 225]
# ID: 56, Bounding Box: [578, 349, 648, 423]
# ID: 54, Bounding Box: [516, 214, 560, 248]
# ID: 55, Bounding Box: [466, 316, 547, 414]
# ID: 53, Bounding Box: [340, 351, 427, 424]
# 0: 384x640 4 cars, 1 truck, 72.2ms
# Speed: 3.6ms preprocess, 72.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 57, Bounding Box: [586, 202, 621, 230]
# ID: 56, Bounding Box: [561, 381, 639, 463]
# ID: 54, Bounding Box: [512, 218, 556, 254]
# ID: 55, Bounding Box: [443, 337, 533, 446]
# ID: 53, Bounding Box: [312, 371, 410, 451]
#
# 0: 384x640 6 cars, 1 truck, 78.7ms
# Speed: 3.0ms preprocess, 78.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 57, Bounding Box: [582, 207, 619, 236]
# ID: 56, Bounding Box: [544, 414, 629, 486]
# ID: 54, Bounding Box: [507, 221, 553, 259]
# ID: 55, Bounding Box: [417, 360, 515, 474]
# ID: 53, Bounding Box: [280, 391, 384, 474]
#
# 0: 384x640 4 cars, 1 bus, 1 truck, 86.3ms
# Speed: 2.0ms preprocess, 86.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 57, Bounding Box: [580, 211, 618, 241]
# ID: 54, Bounding Box: [503, 225, 549, 264]
# ID: 53, Bounding Box: [247, 413, 358, 487]
#
# 0: 384x640 3 cars, 81.1ms
# Speed: 3.0ms preprocess, 81.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 57, Bounding Box: [576, 215, 616, 248]
# ID: 54, Bounding Box: [497, 231, 545, 270]
#
# 0: 384x640 3 cars, 71.5ms
# Speed: 2.7ms preprocess, 71.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 57, Bounding Box: [571, 221, 614, 256]
# ID: 54, Bounding Box: [490, 237, 540, 277]
#
# 0: 384x640 4 cars, 74.7ms
# Speed: 2.0ms preprocess, 74.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 57, Bounding Box: [567, 228, 610, 264]
# ID: 54, Bounding Box: [482, 244, 534, 285]
#
# 0: 384x640 4 cars, 76.7ms
# Speed: 2.0ms preprocess, 76.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 58, Bounding Box: [536, 185, 567, 215]
# ID: 57, Bounding Box: [561, 235, 606, 273]
# ID: 54, Bounding Box: [474, 250, 529, 294]
#
# 0: 384x640 5 cars, 69.2ms
# Speed: 2.0ms preprocess, 69.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 58, Bounding Box: [535, 188, 567, 219]
# ID: 57, Bounding Box: [555, 242, 603, 283]
# ID: 54, Bounding Box: [464, 256, 522, 303]
#
# 0: 384x640 5 cars, 77.3ms
# Speed: 2.0ms preprocess, 77.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 59, Bounding Box: [637, 229, 670, 282]
# ID: 58, Bounding Box: [534, 191, 567, 222]
# ID: 57, Bounding Box: [550, 252, 599, 294]
# ID: 54, Bounding Box: [454, 265, 514, 312]
#
# 0: 384x640 5 cars, 78.3ms
# Speed: 3.0ms preprocess, 78.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 59, Bounding Box: [632, 237, 670, 295]
# ID: 58, Bounding Box: [534, 194, 568, 225]
# ID: 57, Bounding Box: [541, 262, 593, 307]
# ID: 54, Bounding Box: [442, 274, 506, 323]
#
# 0: 384x640 4 cars, 76.3ms
# Speed: 2.0ms preprocess, 76.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 59, Bounding Box: [628, 246, 673, 308]
# ID: 58, Bounding Box: [529, 199, 567, 230]
# ID: 57, Bounding Box: [531, 274, 587, 323]
# ID: 54, Bounding Box: [431, 283, 498, 334]
#
# 0: 384x640 4 cars, 75.3ms
# Speed: 3.0ms preprocess, 75.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 59, Bounding Box: [622, 255, 672, 324]
# ID: 58, Bounding Box: [526, 203, 565, 232]
# ID: 57, Bounding Box: [522, 287, 581, 339]
# ID: 54, Bounding Box: [418, 294, 487, 347]
#
# 0: 384x640 4 cars, 71.7ms
# Speed: 2.0ms preprocess, 71.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 59, Bounding Box: [615, 268, 670, 341]
# ID: 58, Bounding Box: [521, 205, 563, 236]
# ID: 57, Bounding Box: [509, 302, 572, 358]
# ID: 54, Bounding Box: [401, 307, 475, 364]
#
# 0: 384x640 4 cars, 1 truck, 76.2ms
# Speed: 3.0ms preprocess, 76.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 59, Bounding Box: [609, 282, 670, 362]
# ID: 58, Bounding Box: [517, 207, 561, 240]
# ID: 54, Bounding Box: [380, 320, 460, 382]
#
# 0: 384x640 4 cars, 1 truck, 78.2ms
# Speed: 3.0ms preprocess, 78.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 59, Bounding Box: [600, 299, 668, 386]
# ID: 58, Bounding Box: [515, 211, 560, 245]
# ID: 54, Bounding Box: [356, 335, 443, 402]
#
# 0: 384x640 4 cars, 1 truck, 85.1ms
# Speed: 2.0ms preprocess, 85.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 58, Bounding Box: [513, 214, 557, 249]
# ID: 54, Bounding Box: [333, 352, 426, 424]
#
# 0: 384x640 4 cars, 1 truck, 88.8ms
# Speed: 2.0ms preprocess, 88.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 60, Bounding Box: [571, 347, 655, 458]
# ID: 58, Bounding Box: [507, 218, 553, 255]
#
# 0: 384x640 4 cars, 1 truck, 79.7ms
# Speed: 2.0ms preprocess, 79.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 60, Bounding Box: [558, 375, 644, 484]
# ID: 58, Bounding Box: [503, 222, 550, 260]
#
# 0: 384x640 3 cars, 1 truck, 76.8ms
# Speed: 2.0ms preprocess, 76.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 61, Bounding Box: [232, 410, 360, 491]
# ID: 60, Bounding Box: [545, 402, 632, 494]
# ID: 58, Bounding Box: [498, 227, 546, 266]
#
# 0: 384x640 2 cars, 82.8ms
# Speed: 2.5ms preprocess, 82.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 58, Bounding Box: [491, 232, 540, 272]
#
# 0: 384x640 2 cars, 74.8ms
# Speed: 3.5ms preprocess, 74.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 62, Bounding Box: [590, 194, 627, 230]
# ID: 58, Bounding Box: [483, 238, 534, 278]
#
# 0: 384x640 2 cars, 73.2ms
# Speed: 2.0ms preprocess, 73.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 62, Bounding Box: [586, 203, 625, 239]
# ID: 58, Bounding Box: [474, 246, 527, 288]
#
# 0: 384x640 2 cars, 73.2ms
# Speed: 2.5ms preprocess, 73.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 62, Bounding Box: [582, 209, 621, 245]
# ID: 58, Bounding Box: [464, 254, 521, 298]
#
# 0: 384x640 2 cars, 75.8ms
# Speed: 2.0ms preprocess, 75.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# ID: 62, Bounding Box: [575, 213, 618, 253]
# ID: 58, Bounding Box: [453, 262, 512, 309]
#
# 0: 384x640 2 cars, 77.8ms
# Speed: 2.0ms preprocess, 77.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 62, Bounding Box: [569, 219, 615, 262]
# ID: 58, Bounding Box: [441, 271, 505, 321]
#
# 0: 384x640 2 cars, 74.2ms
# Speed: 2.0ms preprocess, 74.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# ID: 62, Bounding Box: [563, 227, 610, 272]
# ID: 58, Bounding Box: [427, 282, 493, 333]
#
# 0: 384x640 2 cars, 78.3ms
# Speed: 1.5ms preprocess, 78.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 62, Bounding Box: [556, 235, 606, 283]
# ID: 58, Bounding Box: [411, 293, 481, 348]
#
# 0: 384x640 2 cars, 82.7ms
# Speed: 2.6ms preprocess, 82.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 62, Bounding Box: [547, 244, 600, 296]
# ID: 58, Bounding Box: [391, 305, 467, 364]
#
# 0: 384x640 2 cars, 73.2ms
# Speed: 2.0ms preprocess, 73.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 62, Bounding Box: [536, 255, 593, 311]
# ID: 58, Bounding Box: [370, 319, 452, 382]
#
# 0: 384x640 2 cars, 73.7ms
# Speed: 3.0ms preprocess, 73.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# ID: 62, Bounding Box: [524, 269, 586, 329]
# ID: 58, Bounding Box: [345, 336, 435, 405]
#
# 0: 384x640 2 cars, 80.3ms
# Speed: 2.0ms preprocess, 80.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 62, Bounding Box: [509, 283, 577, 349]
# ID: 58, Bounding Box: [316, 356, 414, 430]
#
# 0: 384x640 3 cars, 70.2ms
# Speed: 3.0ms preprocess, 70.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 62, Bounding Box: [494, 301, 567, 374]
# ID: 58, Bounding Box: [281, 378, 389, 459]
#
# 0: 384x640 3 cars, 72.2ms
# Speed: 3.0ms preprocess, 72.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 62, Bounding Box: [473, 320, 555, 403]
# ID: 58, Bounding Box: [247, 398, 362, 479]
#
# 0: 384x640 3 cars, 76.8ms
# Speed: 2.0ms preprocess, 76.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 62, Bounding Box: [449, 345, 541, 438]
# ID: 58, Bounding Box: [200, 423, 328, 491]
#
# 0: 384x640 2 cars, 80.8ms
# Speed: 2.0ms preprocess, 80.8ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 62, Bounding Box: [422, 373, 522, 471]
#
# 0: 384x640 2 cars, 1 airplane, 74.2ms
# Speed: 2.0ms preprocess, 74.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 63, Bounding Box: [591, 192, 630, 227]
# ID: 62, Bounding Box: [393, 401, 500, 488]
#
# 0: 384x640 2 cars, 1 airplane, 77.3ms
# Speed: 2.0ms preprocess, 77.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 63, Bounding Box: [588, 197, 627, 233]
#
# 0: 384x640 2 cars, 1 airplane, 72.7ms
# Speed: 2.0ms preprocess, 72.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 63, Bounding Box: [585, 202, 624, 239]
#
# 0: 384x640 1 car, 1 airplane, 74.2ms
# Speed: 2.5ms preprocess, 74.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 63, Bounding Box: [580, 207, 621, 245]
#
# 0: 384x640 1 car, 1 airplane, 77.3ms
# Speed: 8.5ms preprocess, 77.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 63, Bounding Box: [575, 212, 618, 252]

# %%
from ultralytics import YOLO
import cv2
import cvzone
import math
from sort import *

# %%
# Video capture from a file
cap = cv2.VideoCapture('people.mp4')

# Loading the YOLO model
model = YOLO('../Yolo-Weights/yolov8n.pt')

# Object classes
classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]

paused = False  # To control the paused state of the video

# Load the mask image
mask = cv2.imread("mask-1.png")

# Tracking
tracker = Sort(max_age=20, min_hits=3, iou_threshold=0.3)

# Line limits
limitsUp = [103, 161, 296, 161]
limitsDown = [527, 489,735, 489]
totalCountUp = set()  # Use a set to avoid duplicate counts
totalCountDown = set()  # Use a set to avoid duplicate counts

# Dictionary to map SORT IDs to new IDs starting from 1
id_map = {}
next_id = 1

# Define a speed factor to skip frames
speed_factor = 2  # Process every 2nd frame

frame_count = 0

while True:
    if not paused:
        success, img = cap.read()
        if not success:
            break

        # Skip frames based on the speed factor
        if frame_count % speed_factor == 0:
            # Resize mask to match the dimensions of img
            mask = cv2.resize(mask, (img.shape[1], img.shape[0]))

            # Apply bitwise AND operation
            imgRegion = cv2.bitwise_and(img, mask)

            imgGraphics = cv2.imread("graphics-1.png",cv2.IMREAD_UNCHANGED)
            img = cvzone.overlayPNG(img, imgGraphics, (730, 260))
            results = model(imgRegion, stream=True)
            detections = np.empty((0, 5))
            for r in results:
                boxes = r.boxes
                for box in boxes:
                    x1, y1, x2, y2 = box.xyxy[0]
                    x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
                    w, h = x2 - x1, y2 - y1

                    conf = math.ceil((box.conf[0] * 100)) / 100
                    cls = int(box.cls[0])
                    currentClass = classNames[cls]

                    if currentClass == 'person' and conf > 0.3:
                        currentArray = np.array([x1, y1, x2, y2, conf])
                        detections = np.vstack((detections, currentArray))

            resultsTracker = tracker.update(detections)
            cv2.line(img, (limitsUp[0], limitsUp[1]), (limitsUp[2], limitsUp[3]), (0, 0, 255), 5)
            cv2.line(img, (limitsDown[0], limitsDown[1]), (limitsDown[2], limitsDown[3]), (0, 0, 255), 5)

            current_count = set()  # Track current frame counts
            for result in resultsTracker:
                x1, y1, x2, y2, ID = result
                x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)
                w, h = x2 - x1, y2 - y1

                if ID not in id_map:
                    id_map[ID] = next_id
                    next_id += 1
                new_id = id_map[ID]
                print(f"ID: {new_id}, Bounding Box: {[x1, y1, x2, y2]}")
                cvzone.cornerRect(img, (x1, y1, w, h), l=9, rt=2, colorR=(255, 0, 255))
                cvzone.putTextRect(img, f'{new_id}', (max(0, x1), max(35, y1)),
                                   offset=10, scale=2, thickness=3)

                cx, cy = x1 + w // 2, y1 + h // 2
                cv2.circle(img, (cx, cy), 5, (255, 0, 255), cv2.FILLED)

                if limitsUp[0] < cx < limitsUp[2] and limitsUp[1] - 15 < cy < limitsUp[1] + 15:
                    if new_id not in totalCountUp:
                        totalCountUp.add(new_id)  # Add ID to the set
                        cv2.line(img, (limitsUp[0], limitsUp[1]), (limitsUp[2], limitsUp[3]), (0, 255, 0), 5)

                if limitsDown[0] < cx < limitsDown[2] and limitsDown[1] - 15 < cy < limitsDown[1] + 15:
                    if new_id not in totalCountDown:
                        totalCountDown.add(new_id)  # Add ID to the set
                        cv2.line(img, (limitsDown[0], limitsDown[1]), (limitsDown[2], limitsDown[3]), (0, 255, 0), 5)

            cv2.putText(img, str(len(totalCountUp)), (929, 345), cv2.FONT_HERSHEY_PLAIN, 5, (139, 195, 75), 7)
            cv2.putText(img, str(len(totalCountDown)), (1191, 345), cv2.FONT_HERSHEY_PLAIN, 5, (50, 50, 230), 7)

            cv2.imshow("Image", img)
        
        frame_count += 1
        
    key = cv2.waitKey(1) & 0xFF

    if key == ord('p'):  # Pause the video
        paused = True
    elif key == ord('r'):  # Resume the video
        paused = False
    elif key == ord('q'):  # Quit the video
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 3 persons, 78.5ms
# Speed: 0.0ms preprocess, 78.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 1, Bounding Box: [399, 651, 516, 719]
# ID: 2, Bounding Box: [400, 649, 482, 719]
# ID: 3, Bounding Box: [235, 318, 354, 577]
#
# 0: 384x640 3 persons, 100.2ms
# Speed: 1.0ms preprocess, 100.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 1, Bounding Box: [397, 646, 516, 718]
# ID: 2, Bounding Box: [403, 645, 482, 716]
# ID: 3, Bounding Box: [232, 316, 352, 576]
#
# 0: 384x640 2 persons, 94.2ms
# Speed: 15.6ms preprocess, 94.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 1, Bounding Box: [396, 640, 511, 716]
# ID: 3, Bounding Box: [229, 310, 351, 569]
#
# 0: 384x640 2 persons, 78.1ms
# Speed: 12.5ms preprocess, 78.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 1, Bounding Box: [391, 636, 501, 715]
# ID: 3, Bounding Box: [226, 304, 349, 562]
#
# 0: 384x640 3 persons, 78.1ms
# Speed: 15.6ms preprocess, 78.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 1, Bounding Box: [383, 628, 498, 715]
# ID: 3, Bounding Box: [223, 300, 346, 558]
#
# 0: 384x640 2 persons, 63.0ms
# Speed: 15.6ms preprocess, 63.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 3, Bounding Box: [219, 295, 342, 555]
#
# 0: 384x640 2 persons, 78.5ms
# Speed: 0.0ms preprocess, 78.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 3, Bounding Box: [218, 290, 341, 551]
#
# 0: 384x640 2 persons, 78.6ms
# Speed: 0.0ms preprocess, 78.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 3, Bounding Box: [214, 284, 337, 542]
#
# 0: 384x640 2 persons, 78.6ms
# Speed: 0.0ms preprocess, 78.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 1, Bounding Box: [384, 606, 492, 713]
# ID: 3, Bounding Box: [212, 278, 335, 536]
#
# 0: 384x640 2 persons, 78.5ms
# Speed: 0.0ms preprocess, 78.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 1, Bounding Box: [381, 600, 487, 713]
# ID: 3, Bounding Box: [209, 273, 333, 530]
#
# 0: 384x640 2 persons, 73.1ms
# Speed: 0.0ms preprocess, 73.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 1, Bounding Box: [378, 593, 482, 713]
# ID: 3, Bounding Box: [207, 268, 332, 526]
#
# 0: 384x640 2 persons, 78.1ms
# Speed: 0.0ms preprocess, 78.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 1, Bounding Box: [375, 588, 478, 713]
# ID: 3, Bounding Box: [206, 262, 330, 522]
#
# 0: 384x640 2 persons, 78.1ms
# Speed: 0.0ms preprocess, 78.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 1, Bounding Box: [373, 581, 475, 713]
# ID: 3, Bounding Box: [204, 257, 328, 518]
#
# 0: 384x640 2 persons, 78.5ms
# Speed: 0.0ms preprocess, 78.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 1, Bounding Box: [371, 576, 472, 714]
# ID: 3, Bounding Box: [202, 251, 325, 513]
#
# 0: 384x640 2 persons, 67.0ms
# Speed: 0.0ms preprocess, 67.0ms inference, 11.5ms postprocess per image at shape (1, 3, 384, 640)
# ID: 1, Bounding Box: [368, 570, 467, 713]
# ID: 3, Bounding Box: [201, 245, 322, 507]
#
# 0: 384x640 2 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
# ID: 1, Bounding Box: [366, 564, 464, 712]
# ID: 3, Bounding Box: [200, 240, 320, 501]
#
# 0: 384x640 2 persons, 78.5ms
# Speed: 0.0ms preprocess, 78.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 1, Bounding Box: [363, 558, 460, 713]
# ID: 3, Bounding Box: [199, 234, 318, 495]
#
# 0: 384x640 2 persons, 62.9ms
# Speed: 15.6ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 1, Bounding Box: [362, 553, 458, 713]
# ID: 3, Bounding Box: [196, 229, 315, 492]
#
# 0: 384x640 2 persons, 78.5ms
# Speed: 0.0ms preprocess, 78.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 1, Bounding Box: [357, 547, 455, 713]
# ID: 3, Bounding Box: [193, 224, 312, 488]
#
# 0: 384x640 2 persons, 78.6ms
# Speed: 0.0ms preprocess, 78.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 1, Bounding Box: [353, 541, 452, 713]
# ID: 3, Bounding Box: [191, 218, 310, 482]
#
# 0: 384x640 2 persons, 69.0ms
# Speed: 0.0ms preprocess, 69.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 1, Bounding Box: [345, 535, 447, 714]
# ID: 3, Bounding Box: [188, 211, 306, 474]
#
# 0: 384x640 3 persons, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 1, Bounding Box: [340, 530, 443, 714]
# ID: 3, Bounding Box: [186, 206, 303, 469]
#
# 0: 384x640 6 persons, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 15.6ms postprocess per image at shape (1, 3, 384, 640)
# ID: 1, Bounding Box: [338, 523, 441, 713]
# ID: 3, Bounding Box: [185, 201, 302, 465]
#
# 0: 384x640 4 persons, 81.1ms
# Speed: 0.0ms preprocess, 81.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 1, Bounding Box: [333, 519, 438, 714]
# ID: 3, Bounding Box: [182, 197, 300, 463]
#
# 0: 384x640 4 persons, 78.5ms
# Speed: 0.0ms preprocess, 78.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 4, Bounding Box: [419, 661, 483, 719]
# ID: 1, Bounding Box: [329, 515, 435, 716]
# ID: 3, Bounding Box: [179, 190, 298, 456]
#
# 0: 384x640 3 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 5, Bounding Box: [415, 656, 508, 718]
# ID: 1, Bounding Box: [326, 510, 433, 716]
# ID: 3, Bounding Box: [176, 184, 296, 449]
#
# 0: 384x640 4 persons, 78.6ms
# Speed: 0.0ms preprocess, 78.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 5, Bounding Box: [407, 649, 505, 716]
# ID: 1, Bounding Box: [322, 505, 431, 716]
# ID: 3, Bounding Box: [174, 180, 293, 445]
#
# 0: 384x640 4 persons, 63.0ms
# Speed: 0.0ms preprocess, 63.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 5, Bounding Box: [403, 644, 503, 716]
# ID: 1, Bounding Box: [319, 500, 429, 715]
# ID: 3, Bounding Box: [171, 175, 290, 439]
#
# 0: 384x640 3 persons, 78.5ms
# Speed: 0.0ms preprocess, 78.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 5, Bounding Box: [397, 638, 500, 716]
# ID: 1, Bounding Box: [316, 494, 427, 715]
# ID: 3, Bounding Box: [169, 171, 289, 434]
#
# 0: 384x640 3 persons, 78.5ms
# Speed: 0.0ms preprocess, 78.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 5, Bounding Box: [392, 632, 498, 716]
# ID: 1, Bounding Box: [313, 489, 425, 714]
# ID: 3, Bounding Box: [166, 166, 287, 430]
#
# 0: 384x640 3 persons, 63.0ms
# Speed: 0.0ms preprocess, 63.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 5, Bounding Box: [388, 626, 495, 716]
# ID: 1, Bounding Box: [311, 482, 422, 713]
# ID: 3, Bounding Box: [163, 160, 285, 425]
#
# 0: 384x640 4 persons, 63.0ms
# Speed: 0.0ms preprocess, 63.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 5, Bounding Box: [383, 619, 493, 715]
# ID: 1, Bounding Box: [308, 475, 419, 710]
# ID: 3, Bounding Box: [160, 156, 282, 420]
#
# 0: 384x640 3 persons, 52.4ms
# Speed: 10.5ms preprocess, 52.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 5, Bounding Box: [365, 612, 487, 717]
# ID: 1, Bounding Box: [306, 468, 417, 708]
# ID: 3, Bounding Box: [158, 151, 280, 414]
#
# 0: 384x640 3 persons, 61.9ms
# Speed: 0.0ms preprocess, 61.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 5, Bounding Box: [356, 606, 484, 716]
# ID: 1, Bounding Box: [303, 461, 414, 705]
# ID: 3, Bounding Box: [155, 146, 277, 407]
#
# 0: 384x640 4 persons, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 5, Bounding Box: [351, 599, 483, 716]
# ID: 1, Bounding Box: [300, 459, 412, 707]
# ID: 3, Bounding Box: [152, 142, 274, 403]
#
# 0: 384x640 4 persons, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 5, Bounding Box: [352, 593, 483, 716]
# ID: 1, Bounding Box: [298, 452, 409, 707]
# ID: 3, Bounding Box: [149, 138, 271, 400]
#
# 0: 384x640 5 persons, 72.0ms
# Speed: 0.0ms preprocess, 72.0ms inference, 6.5ms postprocess per image at shape (1, 3, 384, 640)
# ID: 5, Bounding Box: [349, 585, 480, 715]
# ID: 1, Bounding Box: [294, 445, 406, 703]
# ID: 3, Bounding Box: [148, 131, 270, 394]
#
# 0: 384x640 5 persons, 62.4ms
# Speed: 0.0ms preprocess, 62.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 5, Bounding Box: [338, 579, 475, 715]
# ID: 1, Bounding Box: [292, 433, 403, 686]
# ID: 3, Bounding Box: [146, 127, 269, 392]
#
# 0: 384x640 5 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 5, Bounding Box: [333, 573, 473, 715]
# ID: 1, Bounding Box: [288, 427, 401, 678]
# ID: 3, Bounding Box: [144, 121, 266, 385]
#
# 0: 384x640 5 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 6, Bounding Box: [527, 676, 590, 719]
# ID: 7, Bounding Box: [387, 0, 474, 179]
# ID: 5, Bounding Box: [328, 567, 470, 715]
# ID: 1, Bounding Box: [285, 419, 396, 665]
# ID: 3, Bounding Box: [141, 115, 264, 380]
#
# 0: 384x640 5 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 6, Bounding Box: [522, 670, 589, 718]
# ID: 7, Bounding Box: [389, 0, 478, 183]
# ID: 5, Bounding Box: [326, 561, 469, 715]
# ID: 1, Bounding Box: [283, 412, 394, 655]
# ID: 3, Bounding Box: [139, 110, 262, 375]
#
# 0: 384x640 6 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 6, Bounding Box: [521, 663, 592, 717]
# ID: 7, Bounding Box: [393, 0, 481, 186]
# ID: 5, Bounding Box: [332, 555, 469, 714]
# ID: 1, Bounding Box: [281, 405, 391, 645]
# ID: 3, Bounding Box: [137, 105, 260, 369]
#
# 0: 384x640 7 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 6, Bounding Box: [517, 657, 591, 717]
# ID: 7, Bounding Box: [396, 1, 484, 190]
# ID: 5, Bounding Box: [323, 546, 464, 713]
# ID: 1, Bounding Box: [280, 399, 388, 637]
# ID: 3, Bounding Box: [135, 99, 259, 365]
#
# 0: 384x640 7 persons, 57.4ms
# Speed: 0.0ms preprocess, 57.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 6, Bounding Box: [511, 650, 590, 716]
# ID: 7, Bounding Box: [399, 1, 488, 193]
# ID: 5, Bounding Box: [325, 537, 463, 712]
# ID: 1, Bounding Box: [277, 394, 385, 630]
# ID: 3, Bounding Box: [133, 94, 257, 361]
#
# 0: 384x640 7 persons, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 8, Bounding Box: [455, 640, 582, 719]
# ID: 6, Bounding Box: [505, 644, 586, 716]
# ID: 7, Bounding Box: [404, 1, 492, 196]
# ID: 5, Bounding Box: [318, 529, 458, 712]
# ID: 1, Bounding Box: [274, 389, 382, 621]
# ID: 3, Bounding Box: [131, 89, 255, 357]
#
# 0: 384x640 8 persons, 86.2ms
# Speed: 0.0ms preprocess, 86.2ms inference, 8.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [339, 1, 423, 148]
# ID: 8, Bounding Box: [449, 633, 585, 719]
# ID: 6, Bounding Box: [501, 636, 587, 716]
# ID: 7, Bounding Box: [408, 2, 494, 199]
# ID: 5, Bounding Box: [324, 518, 459, 710]
# ID: 1, Bounding Box: [272, 385, 380, 615]
# ID: 3, Bounding Box: [129, 84, 254, 353]
#
# 0: 384x640 6 persons, 62.9ms
# Speed: 15.6ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [342, 2, 425, 149]
# ID: 6, Bounding Box: [498, 629, 586, 715]
# ID: 7, Bounding Box: [412, 3, 496, 204]
# ID: 5, Bounding Box: [329, 512, 459, 711]
# ID: 1, Bounding Box: [269, 384, 377, 620]
# ID: 3, Bounding Box: [127, 78, 251, 346]
#
# 0: 384x640 6 persons, 63.0ms
# Speed: 0.0ms preprocess, 63.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [344, 3, 427, 153]
# ID: 6, Bounding Box: [495, 622, 585, 715]
# ID: 7, Bounding Box: [415, 3, 497, 207]
# ID: 5, Bounding Box: [331, 507, 457, 712]
# ID: 1, Bounding Box: [267, 377, 375, 614]
# ID: 3, Bounding Box: [125, 72, 249, 338]
#
# 0: 384x640 7 persons, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [347, 4, 430, 160]
# ID: 6, Bounding Box: [492, 616, 583, 715]
# ID: 7, Bounding Box: [418, 3, 499, 210]
# ID: 5, Bounding Box: [324, 499, 450, 712]
# ID: 1, Bounding Box: [264, 370, 373, 606]
# ID: 3, Bounding Box: [123, 67, 247, 332]
#
# 0: 384x640 6 persons, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [350, 4, 435, 167]
# ID: 6, Bounding Box: [489, 608, 581, 714]
# ID: 7, Bounding Box: [422, 2, 502, 213]
# ID: 5, Bounding Box: [327, 492, 449, 711]
# ID: 1, Bounding Box: [261, 362, 370, 592]
# ID: 3, Bounding Box: [121, 63, 245, 328]
#
# 0: 384x640 6 persons, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [352, 3, 437, 169]
# ID: 6, Bounding Box: [486, 602, 579, 714]
# ID: 7, Bounding Box: [426, 2, 506, 217]
# ID: 5, Bounding Box: [321, 484, 443, 711]
# ID: 1, Bounding Box: [258, 353, 366, 577]
# ID: 3, Bounding Box: [119, 59, 244, 325]
#
# 0: 384x640 6 persons, 66.0ms
# Speed: 0.0ms preprocess, 66.0ms inference, 12.5ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [354, 2, 440, 172]
# ID: 6, Bounding Box: [482, 596, 576, 715]
# ID: 7, Bounding Box: [428, 2, 509, 221]
# ID: 5, Bounding Box: [322, 478, 441, 711]
# ID: 1, Bounding Box: [257, 346, 364, 566]
# ID: 3, Bounding Box: [117, 54, 242, 323]
#
# 0: 384x640 6 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [356, 1, 441, 172]
# ID: 6, Bounding Box: [479, 587, 573, 714]
# ID: 7, Bounding Box: [430, 1, 512, 224]
# ID: 5, Bounding Box: [315, 473, 436, 713]
# ID: 1, Bounding Box: [254, 343, 360, 559]
# ID: 3, Bounding Box: [115, 50, 240, 319]
#
# 0: 384x640 6 persons, 62.4ms
# Speed: 0.0ms preprocess, 62.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [358, 1, 443, 175]
# ID: 6, Bounding Box: [478, 581, 577, 714]
# ID: 7, Bounding Box: [433, 2, 514, 228]
# ID: 5, Bounding Box: [314, 469, 435, 714]
# ID: 1, Bounding Box: [251, 336, 356, 552]
# ID: 3, Bounding Box: [113, 43, 239, 314]
#
# 0: 384x640 6 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [361, 2, 447, 178]
# ID: 6, Bounding Box: [472, 575, 571, 714]
# ID: 7, Bounding Box: [435, 2, 517, 231]
# ID: 5, Bounding Box: [313, 463, 433, 714]
# ID: 1, Bounding Box: [250, 331, 353, 544]
# ID: 3, Bounding Box: [111, 37, 236, 308]
#
# 0: 384x640 6 persons, 50.4ms
# Speed: 12.5ms preprocess, 50.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [362, 2, 449, 181]
# ID: 6, Bounding Box: [467, 569, 564, 714]
# ID: 7, Bounding Box: [436, 2, 519, 235]
# ID: 5, Bounding Box: [299, 457, 426, 713]
# ID: 1, Bounding Box: [247, 320, 349, 532]
# ID: 3, Bounding Box: [109, 33, 231, 303]
#
# 0: 384x640 6 persons, 59.9ms
# Speed: 0.0ms preprocess, 59.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [364, 2, 450, 183]
# ID: 6, Bounding Box: [463, 562, 558, 714]
# ID: 7, Bounding Box: [439, 4, 521, 238]
# ID: 5, Bounding Box: [292, 450, 423, 712]
# ID: 1, Bounding Box: [244, 312, 346, 523]
# ID: 3, Bounding Box: [109, 28, 231, 300]
#
# 0: 384x640 6 persons, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [367, 3, 454, 189]
# ID: 6, Bounding Box: [459, 556, 552, 713]
# ID: 7, Bounding Box: [442, 7, 523, 243]
# ID: 5, Bounding Box: [297, 444, 424, 712]
# ID: 1, Bounding Box: [242, 305, 344, 517]
# ID: 3, Bounding Box: [108, 23, 229, 295]
#
# 0: 384x640 7 persons, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [369, 5, 456, 196]
# ID: 6, Bounding Box: [457, 549, 549, 713]
# ID: 7, Bounding Box: [445, 11, 525, 246]
# ID: 5, Bounding Box: [292, 438, 420, 711]
# ID: 1, Bounding Box: [237, 299, 339, 511]
# ID: 3, Bounding Box: [108, 18, 227, 291]
#
# 0: 384x640 7 persons, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 11.5ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [371, 7, 461, 204]
# ID: 6, Bounding Box: [457, 543, 546, 712]
# ID: 7, Bounding Box: [446, 14, 525, 250]
# ID: 5, Bounding Box: [291, 432, 418, 709]
# ID: 1, Bounding Box: [234, 291, 336, 503]
# ID: 3, Bounding Box: [106, 12, 225, 285]
# 0: 384x640 7 persons, 64.5ms
# Speed: 0.0ms preprocess, 64.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [372, 11, 462, 207]
# ID: 6, Bounding Box: [454, 537, 543, 713]
# ID: 7, Bounding Box: [448, 19, 526, 255]
# ID: 5, Bounding Box: [283, 425, 413, 706]
# ID: 1, Bounding Box: [232, 285, 332, 496]
# ID: 3, Bounding Box: [103, 7, 223, 281]
#
# 0: 384x640 6 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [375, 18, 462, 211]
# ID: 6, Bounding Box: [453, 531, 541, 713]
# ID: 7, Bounding Box: [450, 25, 529, 261]
# ID: 5, Bounding Box: [276, 418, 409, 701]
# ID: 1, Bounding Box: [230, 279, 328, 489]
# ID: 3, Bounding Box: [100, 2, 221, 275]
#
# 0: 384x640 6 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [377, 22, 464, 214]
# ID: 6, Bounding Box: [451, 525, 540, 713]
# ID: 7, Bounding Box: [452, 29, 530, 264]
# ID: 5, Bounding Box: [279, 411, 410, 695]
# ID: 1, Bounding Box: [228, 274, 326, 487]
# ID: 3, Bounding Box: [98, -1, 219, 269]
#
# 0: 384x640 6 persons, 57.9ms
# Speed: 0.0ms preprocess, 57.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [381, 27, 466, 217]
# ID: 6, Bounding Box: [448, 519, 537, 713]
# ID: 7, Bounding Box: [454, 34, 532, 267]
# ID: 5, Bounding Box: [271, 404, 405, 689]
# ID: 1, Bounding Box: [225, 269, 322, 485]
# ID: 3, Bounding Box: [96, -3, 218, 266]
#
# 0: 384x640 6 persons, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [383, 32, 467, 220]
# ID: 6, Bounding Box: [446, 513, 535, 713]
# ID: 7, Bounding Box: [457, 37, 535, 269]
# ID: 5, Bounding Box: [274, 398, 405, 682]
# ID: 1, Bounding Box: [222, 263, 319, 478]
# ID: 3, Bounding Box: [94, -5, 215, 259]
#
# 0: 384x640 6 persons, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [385, 35, 468, 223]
# ID: 6, Bounding Box: [445, 507, 532, 712]
# ID: 7, Bounding Box: [460, 41, 539, 273]
# ID: 5, Bounding Box: [265, 391, 401, 675]
# ID: 1, Bounding Box: [220, 259, 316, 473]
# ID: 3, Bounding Box: [92, -6, 212, 255]
#
# 0: 384x640 7 persons, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [387, 39, 470, 228]
# ID: 6, Bounding Box: [442, 500, 530, 712]
# ID: 7, Bounding Box: [462, 45, 540, 277]
# ID: 5, Bounding Box: [255, 384, 396, 667]
# ID: 1, Bounding Box: [218, 253, 313, 467]
# ID: 3, Bounding Box: [89, -6, 209, 251]
#
# 0: 384x640 6 persons, 66.5ms
# Speed: 0.0ms preprocess, 66.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [391, 45, 474, 235]
# ID: 6, Bounding Box: [440, 495, 527, 712]
# ID: 7, Bounding Box: [463, 47, 542, 281]
# ID: 5, Bounding Box: [244, 381, 391, 662]
# ID: 1, Bounding Box: [216, 247, 311, 459]
# ID: 3, Bounding Box: [86, -5, 207, 247]
#
# 0: 384x640 7 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [393, 48, 476, 237]
# ID: 6, Bounding Box: [438, 489, 524, 712]
# ID: 7, Bounding Box: [467, 53, 545, 286]
# ID: 5, Bounding Box: [241, 376, 391, 657]
# ID: 1, Bounding Box: [213, 242, 308, 456]
# ID: 3, Bounding Box: [84, -2, 206, 246]
#
# 0: 384x640 7 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [396, 52, 480, 243]
# ID: 6, Bounding Box: [437, 484, 521, 713]
# ID: 7, Bounding Box: [469, 59, 548, 291]
# ID: 5, Bounding Box: [252, 370, 394, 651]
# ID: 1, Bounding Box: [210, 235, 304, 449]
# ID: 3, Bounding Box: [82, -2, 203, 243]
#
# 0: 384x640 7 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [398, 56, 483, 248]
# ID: 6, Bounding Box: [435, 477, 518, 712]
# ID: 7, Bounding Box: [472, 63, 549, 295]
# ID: 5, Bounding Box: [245, 365, 389, 645]
# ID: 1, Bounding Box: [208, 231, 302, 442]
# ID: 3, Bounding Box: [81, -3, 201, 239]
#
# 0: 384x640 6 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [400, 60, 484, 252]
# ID: 6, Bounding Box: [432, 471, 515, 713]
# ID: 7, Bounding Box: [475, 67, 552, 299]
# ID: 5, Bounding Box: [239, 361, 385, 640]
# ID: 1, Bounding Box: [204, 227, 298, 438]
# ID: 3, Bounding Box: [79, -5, 199, 232]
#
# 0: 384x640 6 persons, 63.0ms
# Speed: 0.0ms preprocess, 63.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [403, 64, 488, 258]
# ID: 6, Bounding Box: [428, 466, 511, 714]
# ID: 7, Bounding Box: [479, 70, 557, 302]
# ID: 5, Bounding Box: [248, 354, 388, 633]
# ID: 1, Bounding Box: [201, 220, 294, 429]
# ID: 3, Bounding Box: [76, -6, 195, 222]
#
# 0: 384x640 6 persons, 53.9ms
# Speed: 0.0ms preprocess, 53.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [404, 68, 489, 261]
# ID: 6, Bounding Box: [425, 460, 509, 714]
# ID: 7, Bounding Box: [482, 73, 561, 306]
# ID: 5, Bounding Box: [239, 348, 381, 628]
# ID: 1, Bounding Box: [199, 215, 292, 423]
# ID: 3, Bounding Box: [74, -6, 192, 218]
#
# 0: 384x640 6 persons, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [406, 71, 490, 263]
# ID: 6, Bounding Box: [424, 454, 506, 714]
# ID: 7, Bounding Box: [484, 78, 565, 310]
# ID: 5, Bounding Box: [247, 342, 383, 623]
# ID: 1, Bounding Box: [197, 212, 290, 422]
# ID: 3, Bounding Box: [72, -5, 191, 214]
#
# 0: 384x640 6 persons, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [408, 74, 492, 265]
# ID: 6, Bounding Box: [422, 448, 505, 715]
# ID: 7, Bounding Box: [487, 82, 568, 314]
# ID: 5, Bounding Box: [249, 337, 381, 617]
# ID: 1, Bounding Box: [195, 207, 287, 416]
# ID: 3, Bounding Box: [70, -3, 189, 213]
#
# 0: 384x640 6 persons, 64.5ms
# Speed: 0.0ms preprocess, 64.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [411, 78, 495, 267]
# ID: 6, Bounding Box: [421, 442, 504, 714]
# ID: 7, Bounding Box: [489, 85, 570, 317]
# ID: 5, Bounding Box: [239, 331, 374, 611]
# ID: 1, Bounding Box: [192, 200, 285, 409]
# ID: 3, Bounding Box: [67, -4, 187, 209]
#
# 0: 384x640 6 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [415, 82, 499, 269]
# ID: 6, Bounding Box: [418, 436, 500, 714]
# ID: 7, Bounding Box: [490, 88, 572, 321]
# ID: 5, Bounding Box: [239, 326, 372, 605]
# ID: 1, Bounding Box: [191, 195, 283, 401]
# ID: 3, Bounding Box: [64, -4, 185, 205]
#
# 0: 384x640 6 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [416, 88, 500, 274]
# ID: 6, Bounding Box: [414, 429, 496, 712]
# ID: 7, Bounding Box: [493, 93, 574, 325]
# ID: 5, Bounding Box: [242, 320, 372, 600]
# ID: 1, Bounding Box: [190, 188, 282, 394]
# ID: 3, Bounding Box: [63, -3, 184, 202]
#
# 0: 384x640 5 persons, 63.0ms
# Speed: 0.0ms preprocess, 63.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [419, 94, 502, 280]
# ID: 6, Bounding Box: [411, 423, 493, 711]
# ID: 7, Bounding Box: [496, 97, 576, 329]
# ID: 5, Bounding Box: [237, 315, 368, 594]
# ID: 1, Bounding Box: [188, 179, 279, 386]
#
# 0: 384x640 5 persons, 52.4ms
# Speed: 10.5ms preprocess, 52.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [422, 99, 505, 286]
# ID: 6, Bounding Box: [402, 418, 487, 711]
# ID: 7, Bounding Box: [498, 101, 578, 333]
# ID: 5, Bounding Box: [239, 310, 367, 589]
# ID: 1, Bounding Box: [186, 172, 278, 380]
#
# 0: 384x640 5 persons, 61.9ms
# Speed: 0.0ms preprocess, 61.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [425, 103, 507, 288]
# ID: 6, Bounding Box: [395, 412, 483, 711]
# ID: 7, Bounding Box: [500, 104, 580, 337]
# ID: 5, Bounding Box: [240, 305, 364, 583]
# ID: 1, Bounding Box: [184, 162, 276, 369]
#
# 0: 384x640 5 persons, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [428, 107, 510, 293]
# ID: 6, Bounding Box: [396, 403, 484, 704]
# ID: 7, Bounding Box: [502, 108, 581, 340]
# ID: 5, Bounding Box: [237, 300, 360, 580]
# ID: 1, Bounding Box: [180, 158, 273, 365]
#
# 0: 384x640 5 persons, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [431, 110, 513, 296]
# ID: 6, Bounding Box: [393, 398, 482, 700]
# ID: 7, Bounding Box: [504, 113, 583, 344]
# ID: 5, Bounding Box: [234, 294, 356, 574]
# ID: 1, Bounding Box: [177, 154, 270, 360]
#
# 0: 384x640 5 persons, 72.0ms
# Speed: 0.0ms preprocess, 72.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [432, 115, 515, 301]
# ID: 6, Bounding Box: [391, 390, 480, 692]
# ID: 7, Bounding Box: [507, 117, 585, 348]
# ID: 5, Bounding Box: [233, 288, 354, 569]
# ID: 1, Bounding Box: [174, 148, 269, 355]
#
# 0: 384x640 5 persons, 62.4ms
# Speed: 0.0ms preprocess, 62.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [435, 118, 518, 305]
# ID: 6, Bounding Box: [388, 384, 477, 686]
# ID: 7, Bounding Box: [510, 121, 588, 352]
# ID: 5, Bounding Box: [229, 283, 350, 564]
# ID: 1, Bounding Box: [172, 142, 267, 350]
#
# 0: 384x640 5 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [438, 123, 520, 310]
# ID: 6, Bounding Box: [389, 379, 477, 680]
# ID: 7, Bounding Box: [512, 127, 590, 358]
# ID: 5, Bounding Box: [227, 277, 347, 558]
# ID: 1, Bounding Box: [170, 136, 265, 345]
#
# 0: 384x640 5 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [441, 127, 524, 315]
# ID: 6, Bounding Box: [387, 372, 475, 673]
# ID: 7, Bounding Box: [515, 130, 592, 361]
# ID: 5, Bounding Box: [219, 271, 342, 553]
# ID: 1, Bounding Box: [167, 129, 261, 337]
#
# 0: 384x640 5 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [443, 132, 525, 318]
# ID: 6, Bounding Box: [384, 367, 472, 669]
# ID: 7, Bounding Box: [517, 135, 594, 365]
# ID: 5, Bounding Box: [207, 267, 336, 547]
# ID: 1, Bounding Box: [164, 125, 259, 335]
#
# 0: 384x640 5 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [447, 137, 528, 323]
# ID: 6, Bounding Box: [380, 361, 468, 663]
# ID: 7, Bounding Box: [519, 138, 597, 369]
# ID: 5, Bounding Box: [205, 261, 336, 540]
# ID: 1, Bounding Box: [162, 119, 256, 332]
#
# 0: 384x640 5 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [450, 142, 531, 328]
# ID: 6, Bounding Box: [377, 355, 464, 658]
# ID: 7, Bounding Box: [523, 143, 601, 373]
# ID: 5, Bounding Box: [203, 253, 335, 533]
# ID: 1, Bounding Box: [159, 115, 253, 328]
#
# 0: 384x640 5 persons, 57.4ms
# Speed: 0.0ms preprocess, 57.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [453, 146, 534, 332]
# ID: 6, Bounding Box: [371, 351, 460, 655]
# ID: 7, Bounding Box: [526, 148, 603, 377]
# ID: 5, Bounding Box: [200, 247, 332, 528]
# ID: 1, Bounding Box: [158, 112, 251, 326]
#
# 0: 384x640 5 persons, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [457, 152, 537, 339]
# ID: 6, Bounding Box: [365, 345, 456, 651]
# ID: 7, Bounding Box: [529, 152, 606, 382]
# ID: 5, Bounding Box: [204, 244, 332, 524]
# ID: 1, Bounding Box: [156, 106, 252, 322]
#
# 0: 384x640 5 persons, 62.6ms
# Speed: 0.0ms preprocess, 62.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [459, 156, 539, 343]
# ID: 6, Bounding Box: [362, 338, 453, 645]
# ID: 7, Bounding Box: [532, 157, 610, 386]
# ID: 5, Bounding Box: [204, 236, 331, 518]
# ID: 1, Bounding Box: [153, 100, 248, 314]
#
# 0: 384x640 5 persons, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [462, 161, 542, 348]
# ID: 6, Bounding Box: [359, 332, 450, 639]
# ID: 7, Bounding Box: [534, 162, 612, 391]
# ID: 5, Bounding Box: [195, 232, 324, 514]
# ID: 1, Bounding Box: [150, 95, 246, 311]
#
# 0: 384x640 5 persons, 67.0ms
# Speed: 0.0ms preprocess, 67.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [465, 165, 546, 353]
# ID: 6, Bounding Box: [356, 326, 447, 634]
# ID: 7, Bounding Box: [537, 165, 614, 393]
# ID: 5, Bounding Box: [198, 228, 324, 510]
# ID: 1, Bounding Box: [147, 88, 244, 303]
#
# 0: 384x640 5 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [468, 171, 549, 362]
# ID: 6, Bounding Box: [357, 320, 446, 626]
# ID: 7, Bounding Box: [539, 169, 615, 397]
# ID: 5, Bounding Box: [194, 223, 321, 505]
# ID: 1, Bounding Box: [143, 85, 239, 300]
#
# 0: 384x640 6 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [471, 176, 553, 371]
# ID: 6, Bounding Box: [355, 314, 443, 620]
# ID: 7, Bounding Box: [542, 173, 617, 401]
# ID: 5, Bounding Box: [191, 219, 318, 501]
# ID: 1, Bounding Box: [141, 82, 237, 294]
#
# 0: 384x640 5 persons, 63.0ms
# Speed: 0.0ms preprocess, 63.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [475, 181, 557, 376]
# ID: 6, Bounding Box: [353, 308, 441, 612]
# ID: 7, Bounding Box: [546, 179, 622, 406]
# ID: 5, Bounding Box: [193, 213, 318, 496]
# ID: 1, Bounding Box: [139, 84, 235, 295]
#
# 0: 384x640 6 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [477, 185, 559, 378]
# ID: 6, Bounding Box: [349, 303, 437, 608]
# ID: 7, Bounding Box: [549, 185, 625, 412]
# ID: 5, Bounding Box: [190, 206, 315, 490]
# ID: 1, Bounding Box: [137, 71, 232, 280]
#
# 0: 384x640 5 persons, 63.0ms
# Speed: 0.0ms preprocess, 63.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [481, 189, 563, 381]
# ID: 6, Bounding Box: [344, 299, 434, 604]
# ID: 7, Bounding Box: [552, 190, 628, 417]
# ID: 5, Bounding Box: [186, 202, 312, 486]
# ID: 1, Bounding Box: [136, 65, 230, 273]
#
# 0: 384x640 5 persons, 53.5ms
# Speed: 0.0ms preprocess, 53.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [482, 193, 564, 383]
# ID: 6, Bounding Box: [340, 295, 431, 599]
# ID: 7, Bounding Box: [555, 195, 630, 421]
# ID: 5, Bounding Box: [184, 196, 310, 480]
# ID: 1, Bounding Box: [133, 61, 228, 268]
#
# 0: 384x640 5 persons, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [485, 196, 566, 385]
# ID: 6, Bounding Box: [336, 291, 428, 595]
# ID: 7, Bounding Box: [557, 199, 632, 426]
# ID: 5, Bounding Box: [175, 191, 305, 474]
# ID: 1, Bounding Box: [132, 56, 226, 258]
#
# 0: 384x640 5 persons, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [489, 199, 568, 385]
# ID: 6, Bounding Box: [333, 286, 426, 589]
# ID: 7, Bounding Box: [561, 203, 635, 430]
# ID: 5, Bounding Box: [174, 187, 304, 469]
# ID: 1, Bounding Box: [129, 53, 223, 256]
#
# 0: 384x640 5 persons, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [492, 204, 572, 389]
# ID: 6, Bounding Box: [329, 281, 423, 583]
# ID: 7, Bounding Box: [565, 207, 641, 433]
# ID: 5, Bounding Box: [173, 182, 303, 464]
# ID: 1, Bounding Box: [128, 51, 222, 254]
#
# 0: 384x640 5 persons, 71.5ms
# Speed: 0.0ms preprocess, 71.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [495, 211, 575, 396]
# ID: 6, Bounding Box: [328, 276, 421, 578]
# ID: 7, Bounding Box: [567, 213, 646, 440]
# ID: 5, Bounding Box: [171, 177, 300, 458]
# ID: 1, Bounding Box: [125, 47, 219, 247]
#
# 0: 384x640 5 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [497, 216, 578, 403]
# ID: 6, Bounding Box: [325, 271, 418, 573]
# ID: 7, Bounding Box: [570, 217, 649, 444]
# ID: 5, Bounding Box: [161, 172, 296, 454]
# ID: 1, Bounding Box: [124, 42, 217, 242]
# 0: 384x640 5 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [499, 219, 579, 405]
# ID: 6, Bounding Box: [319, 268, 414, 569]
# ID: 7, Bounding Box: [572, 222, 651, 449]
# ID: 5, Bounding Box: [153, 167, 291, 448]
# ID: 1, Bounding Box: [123, 39, 217, 239]
#
# 0: 384x640 5 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [501, 225, 581, 410]
# ID: 6, Bounding Box: [312, 264, 411, 564]
# ID: 7, Bounding Box: [573, 226, 652, 453]
# ID: 5, Bounding Box: [154, 174, 292, 448]
# ID: 1, Bounding Box: [121, 34, 216, 234]
#
# 0: 384x640 5 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [503, 229, 583, 414]
# ID: 6, Bounding Box: [303, 259, 407, 559]
# ID: 7, Bounding Box: [576, 230, 654, 455]
# ID: 5, Bounding Box: [147, 164, 288, 438]
# ID: 1, Bounding Box: [119, 28, 213, 227]
#
# 0: 384x640 5 persons, 63.0ms
# Speed: 0.0ms preprocess, 63.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [505, 233, 585, 416]
# ID: 6, Bounding Box: [295, 256, 404, 554]
# ID: 7, Bounding Box: [578, 234, 656, 458]
# ID: 5, Bounding Box: [146, 161, 286, 433]
# ID: 1, Bounding Box: [116, 22, 211, 222]
#
# 0: 384x640 5 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [509, 240, 589, 425]
# ID: 6, Bounding Box: [289, 252, 401, 549]
# ID: 7, Bounding Box: [579, 239, 657, 462]
# ID: 5, Bounding Box: [147, 152, 285, 426]
# ID: 1, Bounding Box: [113, 18, 209, 217]
#
# 0: 384x640 5 persons, 58.4ms
# Speed: 0.0ms preprocess, 58.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [511, 244, 591, 429]
# ID: 6, Bounding Box: [283, 247, 399, 543]
# ID: 7, Bounding Box: [581, 243, 660, 466]
# ID: 5, Bounding Box: [142, 144, 282, 421]
# ID: 1, Bounding Box: [109, 14, 205, 212]
#
# 0: 384x640 5 persons, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [513, 248, 594, 434]
# ID: 6, Bounding Box: [277, 243, 395, 537]
# ID: 7, Bounding Box: [584, 248, 662, 471]
# ID: 5, Bounding Box: [145, 136, 282, 415]
# ID: 1, Bounding Box: [107, 11, 203, 208]
#
# 0: 384x640 5 persons, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [515, 252, 596, 440]
# ID: 6, Bounding Box: [270, 238, 389, 531]
# ID: 7, Bounding Box: [587, 252, 665, 476]
# ID: 5, Bounding Box: [142, 131, 278, 410]
# ID: 1, Bounding Box: [106, 5, 200, 201]
#
# 0: 384x640 5 persons, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [518, 256, 598, 444]
# ID: 6, Bounding Box: [264, 234, 384, 527]
# ID: 7, Bounding Box: [588, 256, 666, 482]
# ID: 5, Bounding Box: [145, 126, 278, 406]
# ID: 1, Bounding Box: [104, 1, 197, 195]
#
# 0: 384x640 5 persons, 66.0ms
# Speed: 0.0ms preprocess, 66.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [520, 259, 599, 444]
# ID: 6, Bounding Box: [259, 229, 381, 522]
# ID: 7, Bounding Box: [590, 258, 669, 484]
# ID: 5, Bounding Box: [140, 123, 272, 404]
# ID: 1, Bounding Box: [103, 0, 198, 193]
#
# 0: 384x640 5 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [522, 263, 602, 448]
# ID: 6, Bounding Box: [254, 225, 378, 518]
# ID: 7, Bounding Box: [593, 262, 671, 489]
# ID: 5, Bounding Box: [141, 118, 271, 399]
# ID: 1, Bounding Box: [101, -2, 196, 189]
#
# 0: 384x640 5 persons, 62.4ms
# Speed: 0.0ms preprocess, 62.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [525, 267, 604, 451]
# ID: 6, Bounding Box: [249, 218, 375, 511]
# ID: 7, Bounding Box: [595, 266, 673, 493]
# ID: 5, Bounding Box: [136, 109, 267, 390]
# ID: 1, Bounding Box: [96, -4, 191, 185]
#
# 0: 384x640 5 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [528, 274, 607, 458]
# ID: 6, Bounding Box: [245, 215, 374, 507]
# ID: 7, Bounding Box: [597, 271, 675, 497]
# ID: 5, Bounding Box: [135, 106, 266, 388]
# ID: 1, Bounding Box: [93, -4, 188, 182]
#
# 0: 384x640 5 persons, 1 boat, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [530, 278, 610, 462]
# ID: 6, Bounding Box: [242, 212, 373, 502]
# ID: 7, Bounding Box: [598, 278, 676, 504]
# ID: 5, Bounding Box: [139, 107, 266, 390]
# ID: 1, Bounding Box: [92, -3, 185, 182]
#
# 0: 384x640 4 persons, 63.0ms
# Speed: 0.0ms preprocess, 63.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [531, 283, 611, 468]
# ID: 6, Bounding Box: [239, 212, 371, 498]
# ID: 7, Bounding Box: [601, 283, 679, 510]
# ID: 1, Bounding Box: [90, -5, 183, 174]
#
# 0: 384x640 5 persons, 1 boat, 53.9ms
# Speed: 0.0ms preprocess, 53.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [534, 289, 614, 474]
# ID: 6, Bounding Box: [235, 210, 369, 493]
# ID: 7, Bounding Box: [606, 287, 684, 514]
# ID: 1, Bounding Box: [88, -6, 180, 169]
#
# 0: 384x640 5 persons, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [537, 295, 617, 481]
# ID: 6, Bounding Box: [232, 210, 365, 491]
# ID: 7, Bounding Box: [608, 290, 686, 517]
# ID: 1, Bounding Box: [86, -5, 179, 163]
#
# 0: 384x640 5 persons, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [540, 300, 620, 490]
# ID: 6, Bounding Box: [229, 201, 362, 484]
# ID: 7, Bounding Box: [611, 296, 690, 523]
# ID: 1, Bounding Box: [84, -6, 176, 156]
#
# 0: 384x640 5 persons, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [543, 304, 624, 494]
# ID: 6, Bounding Box: [227, 196, 359, 480]
# ID: 7, Bounding Box: [614, 300, 692, 527]
# ID: 1, Bounding Box: [80, -7, 173, 150]
#
# 0: 384x640 5 persons, 70.5ms
# Speed: 0.0ms preprocess, 70.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [545, 308, 626, 497]
# ID: 6, Bounding Box: [225, 190, 356, 476]
# ID: 7, Bounding Box: [616, 305, 695, 532]
# ID: 5, Bounding Box: [120, 71, 247, 357]
# ID: 1, Bounding Box: [80, -5, 176, 148]
#
# 0: 384x640 5 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [548, 311, 629, 499]
# ID: 6, Bounding Box: [222, 184, 353, 473]
# ID: 7, Bounding Box: [619, 309, 698, 537]
# ID: 5, Bounding Box: [121, 66, 245, 351]
# ID: 1, Bounding Box: [82, -5, 184, 144]
#
# 0: 384x640 5 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [550, 316, 630, 505]
# ID: 6, Bounding Box: [221, 173, 352, 466]
# ID: 7, Bounding Box: [622, 313, 700, 541]
# ID: 5, Bounding Box: [120, 61, 242, 346]
#
# 0: 384x640 5 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [553, 321, 633, 509]
# ID: 6, Bounding Box: [218, 164, 349, 461]
# ID: 7, Bounding Box: [625, 318, 703, 546]
# ID: 5, Bounding Box: [118, 56, 240, 341]
#
# 0: 384x640 4 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [556, 326, 636, 516]
# ID: 6, Bounding Box: [215, 166, 345, 459]
# ID: 7, Bounding Box: [627, 323, 705, 552]
# ID: 5, Bounding Box: [116, 47, 237, 327]
#
# 0: 384x640 5 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [558, 330, 638, 521]
# ID: 6, Bounding Box: [212, 159, 341, 452]
# ID: 7, Bounding Box: [630, 328, 706, 557]
# ID: 5, Bounding Box: [115, 41, 234, 318]
#
# 0: 384x640 4 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [561, 333, 640, 523]
# ID: 6, Bounding Box: [208, 154, 337, 448]
# ID: 7, Bounding Box: [632, 333, 709, 561]
# ID: 5, Bounding Box: [109, 40, 230, 314]
# 0: 384x640 4 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [563, 339, 643, 527]
# ID: 6, Bounding Box: [205, 149, 335, 441]
# ID: 7, Bounding Box: [635, 338, 712, 567]
# ID: 5, Bounding Box: [110, 37, 230, 309]
#
# 0: 384x640 4 persons, 53.4ms
# Speed: 0.0ms preprocess, 53.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [566, 343, 645, 531]
# ID: 6, Bounding Box: [202, 143, 332, 433]
# ID: 7, Bounding Box: [640, 343, 716, 572]
# ID: 5, Bounding Box: [110, 31, 227, 301]
#
# 0: 384x640 4 persons, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [569, 349, 648, 537]
# ID: 6, Bounding Box: [200, 140, 331, 428]
# ID: 7, Bounding Box: [641, 348, 718, 576]
# ID: 5, Bounding Box: [108, 25, 225, 291]
#
# 0: 384x640 4 persons, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [572, 354, 651, 540]
# ID: 6, Bounding Box: [198, 131, 330, 421]
# ID: 7, Bounding Box: [644, 353, 721, 581]
# ID: 5, Bounding Box: [107, 24, 222, 290]
#
# 0: 384x640 4 persons, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [574, 359, 653, 544]
# ID: 6, Bounding Box: [197, 125, 332, 415]
# ID: 7, Bounding Box: [645, 358, 722, 586]
# ID: 5, Bounding Box: [107, 19, 220, 287]
#
# 0: 384x640 3 persons, 71.5ms
# Speed: 0.0ms preprocess, 71.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [577, 365, 656, 551]
# ID: 6, Bounding Box: [197, 122, 333, 410]
# ID: 7, Bounding Box: [648, 362, 726, 591]
#
# 0: 384x640 4 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [580, 369, 659, 554]
# ID: 6, Bounding Box: [196, 114, 335, 405]
# ID: 7, Bounding Box: [653, 367, 730, 596]
#
# 0: 384x640 4 persons, 68.0ms
# Speed: 0.0ms preprocess, 68.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [582, 374, 661, 557]
# ID: 6, Bounding Box: [195, 106, 337, 400]
# ID: 7, Bounding Box: [655, 371, 734, 600]
#
# 0: 384x640 4 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [585, 381, 664, 565]
# ID: 6, Bounding Box: [196, 100, 337, 395]
# ID: 7, Bounding Box: [657, 375, 737, 606]
#
# 0: 384x640 4 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [588, 387, 667, 573]
# ID: 6, Bounding Box: [197, 94, 339, 391]
# ID: 7, Bounding Box: [662, 379, 745, 611]
#
# 0: 384x640 4 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [591, 391, 669, 576]
# ID: 6, Bounding Box: [198, 88, 339, 387]
# ID: 7, Bounding Box: [663, 385, 746, 616]
# ID: 5, Bounding Box: [92, 0, 212, 275]
#
# 0: 384x640 4 persons, 63.0ms
# Speed: 0.0ms preprocess, 63.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [594, 394, 672, 579]
# ID: 6, Bounding Box: [199, 82, 338, 381]
# ID: 7, Bounding Box: [666, 389, 749, 619]
# ID: 5, Bounding Box: [92, 0, 212, 277]
#
# 0: 384x640 4 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [596, 400, 674, 583]
# ID: 6, Bounding Box: [203, 76, 339, 377]
# ID: 7, Bounding Box: [667, 393, 751, 623]
# ID: 5, Bounding Box: [91, 0, 212, 276]
#
# 0: 384x640 4 persons, 52.4ms
# Speed: 10.5ms preprocess, 52.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [599, 405, 677, 587]
# ID: 6, Bounding Box: [205, 70, 337, 372]
# ID: 7, Bounding Box: [671, 400, 754, 631]
# ID: 5, Bounding Box: [83, -4, 206, 265]
#
# 0: 384x640 5 persons, 61.9ms
# Speed: 0.0ms preprocess, 61.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [603, 414, 683, 606]
# ID: 6, Bounding Box: [209, 65, 337, 367]
# ID: 7, Bounding Box: [673, 405, 755, 637]
# ID: 5, Bounding Box: [82, -3, 205, 266]
#
# 0: 384x640 4 persons, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [606, 415, 685, 602]
# ID: 6, Bounding Box: [213, 58, 335, 362]
# ID: 7, Bounding Box: [675, 409, 757, 641]
# ID: 5, Bounding Box: [81, -3, 203, 264]
#
# 0: 384x640 4 persons, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [608, 420, 687, 607]
# ID: 6, Bounding Box: [216, 53, 333, 357]
# ID: 7, Bounding Box: [677, 414, 758, 645]
# ID: 5, Bounding Box: [82, -3, 204, 261]
#
# 0: 384x640 4 persons, 72.0ms
# Speed: 0.0ms preprocess, 72.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [611, 423, 689, 608]
# ID: 6, Bounding Box: [219, 48, 331, 351]
# ID: 7, Bounding Box: [680, 418, 760, 650]
#
# 0: 384x640 4 persons, 62.4ms
# Speed: 0.0ms preprocess, 62.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [613, 428, 691, 610]
# ID: 6, Bounding Box: [221, 42, 330, 345]
# ID: 7, Bounding Box: [684, 423, 765, 655]
#
# 0: 384x640 4 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [615, 435, 693, 617]
# ID: 6, Bounding Box: [223, 37, 329, 339]
# ID: 7, Bounding Box: [688, 428, 769, 659]
#
# 0: 384x640 4 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [618, 443, 697, 628]
# ID: 6, Bounding Box: [222, 32, 327, 333]
# ID: 7, Bounding Box: [690, 434, 772, 668]
#
# 0: 384x640 3 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [621, 449, 700, 637]
# ID: 6, Bounding Box: [219, 28, 323, 328]
# ID: 7, Bounding Box: [691, 439, 775, 674]
#
# 0: 384x640 3 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [624, 454, 703, 644]
# ID: 6, Bounding Box: [216, 24, 321, 324]
# ID: 7, Bounding Box: [694, 442, 779, 677]
#
# 0: 384x640 4 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [626, 460, 706, 653]
# ID: 6, Bounding Box: [212, 21, 318, 321]
# ID: 7, Bounding Box: [697, 446, 782, 680]
#
# 0: 384x640 4 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [629, 464, 708, 657]
# ID: 6, Bounding Box: [209, 19, 315, 317]
# ID: 7, Bounding Box: [700, 451, 783, 686]
#
# 0: 384x640 4 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [632, 473, 712, 672]
# ID: 6, Bounding Box: [205, 16, 312, 314]
# ID: 7, Bounding Box: [703, 457, 786, 692]
# ID: 5, Bounding Box: [45, -5, 184, 216]
#
# 0: 384x640 4 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [635, 472, 717, 669]
# ID: 6, Bounding Box: [201, 10, 310, 309]
# ID: 7, Bounding Box: [706, 462, 789, 698]
# ID: 5, Bounding Box: [46, -5, 182, 211]
#
# 0: 384x640 5 persons, 54.9ms
# Speed: 0.0ms preprocess, 54.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [638, 474, 719, 668]
# ID: 6, Bounding Box: [196, 5, 307, 305]
# ID: 7, Bounding Box: [708, 467, 792, 703]
# ID: 5, Bounding Box: [44, -5, 180, 207]
#
# 0: 384x640 4 persons, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [640, 479, 721, 673]
# ID: 6, Bounding Box: [190, 0, 303, 300]
# ID: 7, Bounding Box: [711, 471, 795, 706]
#
# 0: 384x640 4 persons, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [643, 491, 724, 689]
# ID: 6, Bounding Box: [183, -2, 298, 296]
# ID: 7, Bounding Box: [713, 476, 797, 711]
#
# 0: 384x640 3 persons, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [646, 489, 727, 679]
# ID: 6, Bounding Box: [174, -3, 294, 293]
# ID: 7, Bounding Box: [718, 480, 801, 715]
#
# 0: 384x640 3 persons, 69.5ms
# Speed: 0.0ms preprocess, 69.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [649, 500, 732, 697]
# ID: 6, Bounding Box: [166, -4, 290, 291]
# ID: 7, Bounding Box: [720, 485, 803, 719]
#
# 0: 384x640 3 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [653, 509, 735, 709]
# ID: 6, Bounding Box: [155, -4, 284, 288]
# ID: 7, Bounding Box: [723, 489, 806, 722]
#
# 0: 384x640 3 persons, 66.0ms
# Speed: 0.0ms preprocess, 66.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [656, 513, 738, 714]
# ID: 6, Bounding Box: [147, -5, 281, 286]
# ID: 7, Bounding Box: [726, 495, 808, 724]
#
# 0: 384x640 3 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [658, 516, 740, 718]
# ID: 6, Bounding Box: [136, -5, 274, 282]
# ID: 7, Bounding Box: [729, 501, 812, 726]
#
# 0: 384x640 3 persons, 62.4ms
# Speed: 0.0ms preprocess, 62.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [662, 519, 743, 720]
# ID: 6, Bounding Box: [125, -6, 266, 277]
# ID: 7, Bounding Box: [733, 504, 815, 726]
#
# 0: 384x640 3 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [664, 523, 747, 722]
# ID: 6, Bounding Box: [118, -6, 260, 274]
# ID: 7, Bounding Box: [736, 508, 818, 725]
#
# 0: 384x640 3 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [668, 528, 750, 722]
# ID: 6, Bounding Box: [111, -5, 254, 270]
# ID: 7, Bounding Box: [739, 514, 821, 725]
#
# 0: 384x640 3 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [672, 533, 755, 723]
# ID: 6, Bounding Box: [105, -5, 248, 266]
# ID: 7, Bounding Box: [744, 518, 825, 725]
#
# 0: 384x640 3 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [674, 538, 757, 723]
# ID: 6, Bounding Box: [101, -5, 242, 262]
# ID: 7, Bounding Box: [748, 522, 829, 726]
#
# 0: 384x640 3 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [678, 543, 760, 724]
# ID: 6, Bounding Box: [99, -6, 239, 257]
# ID: 7, Bounding Box: [751, 527, 832, 726]
#
# 0: 384x640 3 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [681, 547, 764, 723]
# ID: 6, Bounding Box: [97, -6, 236, 253]
# ID: 7, Bounding Box: [754, 532, 834, 726]
#
# 0: 384x640 3 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [684, 552, 766, 723]
# ID: 6, Bounding Box: [96, -6, 233, 248]
# ID: 7, Bounding Box: [758, 539, 838, 727]
#
# 0: 384x640 3 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [687, 558, 770, 724]
# ID: 6, Bounding Box: [96, -7, 233, 243]
# ID: 7, Bounding Box: [762, 544, 842, 727]
#
# 0: 384x640 3 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [690, 564, 772, 725]
# ID: 6, Bounding Box: [96, -6, 233, 238]
# ID: 7, Bounding Box: [764, 548, 843, 726]
#
# 0: 384x640 3 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [693, 570, 776, 726]
# ID: 6, Bounding Box: [96, -6, 233, 234]
# ID: 7, Bounding Box: [768, 552, 849, 725]
#
# 0: 384x640 3 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [697, 576, 780, 727]
# ID: 6, Bounding Box: [95, -6, 235, 231]
# ID: 7, Bounding Box: [770, 557, 852, 726]
#
# 0: 384x640 3 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [702, 580, 784, 726]
# ID: 6, Bounding Box: [95, -6, 236, 226]
# ID: 7, Bounding Box: [774, 564, 855, 727]
#
# 0: 384x640 3 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [705, 584, 787, 726]
# ID: 6, Bounding Box: [94, -6, 236, 221]
# ID: 7, Bounding Box: [778, 570, 859, 726]
#
# 0: 384x640 3 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [708, 591, 789, 727]
# ID: 6, Bounding Box: [91, -7, 233, 214]
# ID: 7, Bounding Box: [781, 577, 862, 726]
#
# 0: 384x640 3 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [711, 598, 792, 727]
# ID: 6, Bounding Box: [91, -6, 233, 210]
# ID: 7, Bounding Box: [783, 583, 864, 726]
#
# 0: 384x640 3 persons, 63.0ms
# Speed: 0.0ms preprocess, 63.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [715, 604, 796, 727]
# ID: 6, Bounding Box: [91, -6, 233, 207]
# ID: 7, Bounding Box: [787, 589, 868, 727]
#
# 0: 384x640 3 persons, 53.4ms
# Speed: 9.5ms preprocess, 53.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [719, 609, 800, 726]
# ID: 6, Bounding Box: [92, -6, 232, 202]
# ID: 7, Bounding Box: [790, 594, 871, 726]
#
# 0: 384x640 3 persons, 62.4ms
# Speed: 0.0ms preprocess, 62.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [721, 615, 803, 727]
# ID: 6, Bounding Box: [94, -6, 231, 199]
# ID: 7, Bounding Box: [794, 600, 876, 726]
#
# 0: 384x640 3 persons, 56.4ms
# Speed: 0.0ms preprocess, 56.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [725, 623, 806, 727]
# ID: 6, Bounding Box: [97, -6, 231, 195]
# ID: 7, Bounding Box: [797, 606, 879, 726]
#
# 0: 384x640 3 persons, 50.4ms
# Speed: 12.5ms preprocess, 50.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 9, Bounding Box: [728, 631, 810, 728]
# ID: 6, Bounding Box: [101, -5, 232, 192]
# ID: 7, Bounding Box: [801, 611, 882, 726]
#
# 0: 384x640 2 persons, 59.9ms
# Speed: 0.0ms preprocess, 59.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 6, Bounding Box: [103, -5, 231, 187]
# ID: 7, Bounding Box: [805, 617, 886, 726]
#
# 0: 384x640 3 persons, 53.9ms
# Speed: 0.0ms preprocess, 53.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 6, Bounding Box: [104, -6, 229, 182]
# ID: 7, Bounding Box: [810, 624, 890, 726]
#
# 0: 384x640 3 persons, 62.5ms
# Speed: 0.0ms preprocess, 62.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 6, Bounding Box: [104, -6, 226, 177]
# ID: 7, Bounding Box: [813, 630, 896, 726]
#
# 0: 384x640 2 persons, 57.4ms
# Speed: 0.0ms preprocess, 57.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 6, Bounding Box: [105, -6, 224, 173]
# ID: 7, Bounding Box: [815, 636, 899, 726]
#
# 0: 384x640 3 persons, 51.4ms
# Speed: 11.5ms preprocess, 51.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 6, Bounding Box: [106, -5, 221, 169]
# ID: 7, Bounding Box: [818, 642, 902, 726]
#
# 0: 384x640 2 persons, 63.0ms
# Speed: 0.0ms preprocess, 63.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 6, Bounding Box: [106, -5, 218, 165]
# ID: 7, Bounding Box: [827, 647, 909, 726]
#
# 0: 384x640 2 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 6, Bounding Box: [104, -5, 215, 160]
# ID: 7, Bounding Box: [836, 654, 916, 726]
#
# 0: 384x640 2 persons, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# ID: 6, Bounding Box: [103, -5, 212, 156]
# ID: 7, Bounding Box: [843, 659, 921, 726]
#
# 0: 384x640 (no detections), 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 62.9ms
# Speed: 0.0ms preprocess, 62.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 66.0ms
# Speed: 0.0ms preprocess, 66.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
